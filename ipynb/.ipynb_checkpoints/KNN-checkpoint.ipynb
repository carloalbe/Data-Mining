# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from scikitplot.metrics import plot_roc
from scikitplot.metrics import plot_precision_recall
from scikitplot.metrics import plot_cumulative_gain
from scikitplot.metrics import plot_lift_curve

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %% [markdown]
# # Data import

# %%
df=pd.read_csv(r'../data/datatraining.txt')

# %%
df['date'] =  pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
df['Time']= df['date'].apply(lambda x:x.time())
df['Date']= df['date'].apply(lambda x:x.date())
df['Time'] =  pd.to_timedelta(str(x) for x in df['Time'])
df['Date'] =  pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.drop('date', axis=1, inplace=True)

df.drop('HumidityRatio',inplace=True,axis=1)
df=df[df['Light']<10000]

# %%
test=pd.read_csv(r'../data/datatest.txt')

# %%
test['date'] =  pd.to_datetime(test['date'], format='%Y-%m-%d %H:%M:%S')
test['Time']= test['date'].apply(lambda x:x.time())
test['Date']= test['date'].apply(lambda x:x.date())
test['Time'] =  pd.to_timedelta(str(x) for x in test['Time'])
test['Date'] =  pd.to_datetime(test['Date'], format='%Y-%m-%d')
test.drop('date', axis=1, inplace=True)

test.drop('HumidityRatio',inplace=True,axis=1)

# %%
df['Holidays'] = df['Date'].apply(lambda x: 0 if x.weekday()<5 else 1 )
test['Holidays'] = test['Date'].apply(lambda x: 0 if x.weekday()<5 else 1 )

# %% [markdown]
# # k Nearest Neighbor

# %%
attributes = ['Temperature','CO2','Light','Humidity'] 

    
X_train =df[attributes].values
y_train=df['Occupancy'].values
X_test=test[attributes].values
y_test=test['Occupancy'].values

attributes
# Out:
# ['Temperature', 'CO2', 'Light', 'Humidity']

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## optimal K?

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
# Creating odd list K for KNN
neighbors = list(range(15,76,2))
# empty list that will hold cv scores
cv_scores = [ ]
#perform 10-fold cross-validation
for K in neighbors:
    knn = KNeighborsClassifier(n_neighbors = K)
    scores = cross_val_score(knn,X_train,y_train,cv = 10,scoring =
    "accuracy")
    cv_scores.append(scores.mean())

# %%
# Changing to mis classification error
mse = [1-x for x in cv_scores]
# determing best k
optimal_k = neighbors[mse.index(min(mse))]
print("The optimal no. of neighbors is {}".format(optimal_k))
# Out:
# The optimal no. of neighbors is 31

# %%
import matplotlib.pyplot as plt
def plot_accuracy(knn_list_scores):
    pd.DataFrame({"K":[i for i in range(15,76,2)], "Accuracy":knn_list_scores}).set_index("K").plot.bar(figsize= (9,6),ylim=(0.95,0.99),rot=0)
    plt.show()
plot_accuracy(cv_scores)

# %%
plt.plot(range(15,76,2), cv_scores)
plt.ylabel('Accuracy', fontsize=22)
plt.xlabel('K', fontsize=22)
plt.tick_params(axis='both', which='major', labelsize=22)
plt.show()

# %% [markdown]
# ## classification
#
# Prova diverse combinazioni wight algorithm n_neighbors

# %%
clf = KNeighborsClassifier(n_neighbors=51, weights='uniform')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9782363977485928
# F1-score [0.98259304 0.97097097]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1693
#            1       0.95      1.00      0.97       972
#
#     accuracy                           0.98      2665
#    macro avg       0.97      0.98      0.98      2665
# weighted avg       0.98      0.98      0.98      2665

# %%
clf = KNeighborsClassifier(n_neighbors=91, weights='uniform')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9778611632270169
# F1-score [0.98229823 0.97045568]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1693
#            1       0.95      1.00      0.97       972
#
#     accuracy                           0.98      2665
#    macro avg       0.97      0.98      0.98      2665
# weighted avg       0.98      0.98      0.98      2665

# %%
clf = KNeighborsClassifier(n_neighbors=45, weights='distance', algorithm='brute')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9782363977485928
# F1-score [0.98259304 0.97097097]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1693
#            1       0.95      1.00      0.97       972
#
#     accuracy                           0.98      2665
#    macro avg       0.97      0.98      0.98      2665
# weighted avg       0.98      0.98      0.98      2665

# %% [markdown]
# ### Cross Validation

# %%
scores = cross_val_score(clf, X_train, y_train, cv=10)
print('Accuracy: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))

scores = cross_val_score(clf, X_train, y_train, cv=10, scoring='f1_macro')
print('F1-score: %0.4f (+/- %0.3f)' % (scores.mean(), scores.std()))
# Out:
# Accuracy: 0.9745 (+/- 0.031)
# F1-score: 0.9652 (+/- 0.041)

# %% [markdown]
# ### Grid Search

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_neighbors': np.arange(15, 76,2), 'weights':['uniform', 'distance']}

knn = KNeighborsClassifier()
search = GridSearchCV(knn, parameters)
search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                             metric='minkowski',
#                                             metric_params=None, n_jobs=None,
#                                             n_neighbors=5, p=2,
#                                             weights='uniform'),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_neighbors': array([15, 17, 19, 21, 23, 25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45, 47,
#        49, 51, 53, 55, 57, 59, 61, 63, 65, 67, 69, 71, 73, 75]),
#                          'weights': ['uniform', 'distance']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
clf = search.best_estimator_

# %%
y_score=clf.predict_proba(X_test)

# %%
y_pred = clf.predict(X_test)
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9782363977485928
# F1-score [0.98259304 0.97097097]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98      1693
#            1       0.95      1.00      0.97       972
#
#     accuracy                           0.98      2665
#    macro avg       0.97      0.98      0.98      2665
# weighted avg       0.98      0.98      0.98      2665

# %%
search.best_estimator_
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=45, p=2,
#                      weights='uniform')

# %% [markdown]
# ## EVALUATION

# %%
plot_roc(y_test, y_score)
plt.show()

# %%
plot_precision_recall(y_test, y_score)
plt.show()

# %%
plot_lift_curve(y_test, y_score)
plt.show()

# %%
plot_cumulative_gain(y_test, y_score)
plt.show()

# %%
fpr, tpr, thr = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler()

# %%
scaler = MinMaxScaler()

attributes = ['Temperature','CO2','Light','Humidity'] 

    
X_train =pd.DataFrame(scaler.fit_transform(df[attributes])).values
y_train=df['Occupancy'].values
X_test=pd.DataFrame(scaler.fit(df[attributes]).transform(test[attributes])).values
y_test=test['Occupancy'].values

attributes
