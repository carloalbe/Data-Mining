# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter
from collections import defaultdict

# %%
df=pd.read_csv(r'../data/datatraining.txt')
test1=pd.read_csv(r'../data/datatest.txt')
test2=pd.read_csv(r'../data/datatest2.txt')
df=df.append(test1)
df=df.append(test2)

# %%
df['date'] =  pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
df['Time']= df['date'].apply(lambda x:x.time())
df['Date']= df['date'].apply(lambda x:x.date())
df['Time'] =  pd.to_timedelta(str(x) for x in df['Time'])
df['Date'] =  pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.drop('date', axis=1, inplace=True)

df['time']=df['Time'].apply(lambda x:int(str(x)[7:9]+str(x)[10:12]))
#df['time'] = df['time'].astype(int)
df['Holiday'] = df['Date'].apply(lambda x: 0 if x.weekday()<5 else 1 )
df=df[df['Light']<1000]

print(df['Occupancy'].value_counts(normalize=True))
df['Occupancy'].value_counts()
# Out:
# 0    0.769208
# 1    0.230792
# Name: Occupancy, dtype: float64
# 0    15808
# 1     4743
# Name: Occupancy, dtype: int64

# %%
df = df[df['Holiday']==0]                                            #TOLGO TUTTI I SABATI E LE DOMENICHE

df = df[df['time']<1825]                                             #TOLGO DOP LE 18:35

df = df[df['time']>735]                                              #TOLGO PRIMA DELLE 7:35                                       

df = df[df['Light']>388]                                             #TOLGO TUTTI CON MENO LUCE DI 380
print(df['Occupancy'].value_counts())
print(df['Occupancy'].value_counts(normalize=True))
# Out:
# 1    4717
# 0     183
# Name: Occupancy, dtype: int64
# 1    0.962653
# 0    0.037347
# Name: Occupancy, dtype: float64

# %%
df.drop(['Date','time'],axis=1,inplace=True)

# %% [markdown]
# # Data Partitioning

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
from sklearn.model_selection import train_test_split
training, test = train_test_split(df[[col for col in df.columns]], test_size=0.3, random_state=100, stratify=df['Occupancy'])

# %%
attributes = ['Temperature', 'Humidity', 'Light', 'CO2', 'Holiday']

X_train =training[attributes].copy()
y_train=training['Occupancy'].values
X_test=test[attributes].copy()
y_test=test['Occupancy'].values

# %%
np.unique(y_train, return_counts=True), np.unique(y_test, return_counts=True)
# Out:
# ((array([0, 1], dtype=int64), array([ 128, 3302], dtype=int64)),
#  (array([0, 1], dtype=int64), array([  55, 1415], dtype=int64)))

# %% [markdown]
# # Classification

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(min_samples_leaf=10, random_state=42)
clf.fit(X_train, y_train)

y_pred0 = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred0))
print('F1-score %s' % f1_score(y_test, y_pred0, average=None))
print(classification_report(y_test, y_pred0))
# Out:
# Accuracy 0.964625850340136
# F1-score [0.52727273 0.98162544]
#               precision    recall  f1-score   support
#
#            0       0.53      0.53      0.53        55
#            1       0.98      0.98      0.98      1415
#
#     accuracy                           0.96      1470
#    macro avg       0.75      0.75      0.75      1470
# weighted avg       0.96      0.96      0.96      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9761904761904762
# F1-score [0.58823529 0.98774081]
#               precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        55
#            1       0.98      1.00      0.99      1415
#
#     accuracy                           0.98      1470
#    macro avg       0.91      0.73      0.79      1470
# weighted avg       0.97      0.98      0.97      1470

# %% [markdown]
# # ROC curve

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
y_score = clf.predict_proba(X_test)
fpr0, tpr0, _ = roc_curve(y_test, y_score[:, 1])
roc_auc0 = auc(fpr0, tpr0)

# %%
plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %% [markdown]
# # Adjust the Decision Threshold

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_train, y_train)

def adjusted_predict(X, thr=0.96):
    y_score = clf.predict_proba(X_test)[:, 1]
    return np.array([1 if y > thr else 0 for y in y_score])

y_pred = adjusted_predict(X_test, thr=0.96)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, thr = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9414965986394558
# F1-score [0.44871795 0.9691092 ]
#               precision    recall  f1-score   support
#
#            0       0.35      0.64      0.45        55
#            1       0.99      0.95      0.97      1415
#
#     accuracy                           0.94      1470
#    macro avg       0.67      0.79      0.71      1470
# weighted avg       0.96      0.94      0.95      1470

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
X_train.shape
# Out:
# (3430, 5)

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_train)

# %%
X_pca.shape
# Out:
# (3430, 2)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_train, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %% [markdown]
# # Undersampling

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.under_sampling import CondensedNearestNeighbour
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\carlo\Anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
fig, axes = plt.subplots(1, 4, figsize=(20,3))

rus = RandomUnderSampler(random_state=42,sampling_strategy='majority')
X_res, y_res = rus.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[0].set_title("Random Undersapling")

cnn = CondensedNearestNeighbour(random_state=42, n_jobs=10)
X_res, y_res = cnn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[1].set_title("Condensed Nearest Neighbour")

from imblearn.under_sampling import TomekLinks
tl = TomekLinks(sampling_strategy='majority')
X_res, y_res = cnn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[2].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[2].set_title("Tomek Links")

from imblearn.under_sampling import OneSidedSelection #non funziona non si sa perche 
from imblearn.under_sampling import InstanceHardnessThreshold #neanche funziona
from imblearn.under_sampling import NearMiss
nm = InstanceHardnessThreshold(sampling_strategy=1)
X_res, y_res = nm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[3].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[3].set_title("Near Miss")


plt.show()
# Out:
# Resampled dataset shape Counter({0: 128, 1: 128})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-50fe2a7ed682> in <module>
#      11
#      12 cnn = CondensedNearestNeighbour(random_state=42, n_jobs=10)
# ---> 13 X_res, y_res = cnn.fit_resample(X_train, y_train)
#      14 print('Resampled dataset shape %s' % Counter(y_res))
#      15 pca = PCA(n_components=2)
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (label_binarize(output[1], np.unique(y))
#
# ~\Anaconda3\lib\site-packages\imblearn\under_sampling\_prototype_selection\_condensed_nearest_neighbour.py in _fit_resample(self, X, y)
#     196                         # Classify all the element in S and avoid to test the
#     197                         # well classified elements
# --> 198                         pred_S_y = self.estimator_.predict(S_x)
#     199                         good_classif_label = np.unique(
#     200                             np.append(
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     185         for k, classes_k in enumerate(classes_):
#     186             if weights is None:
# --> 187                 mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#     188             else:
#     189                 mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in mode(a, axis, nan_policy)
#     487     counts = np.zeros(a_view.shape[:-1], dtype=np.int)
#     488     for ind in inds:
# --> 489         modes[ind], counts[ind] = _mode1D(a_view[ind])
#     490     newshape = list(a.shape)
#     491     newshape[axis] = 1
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in _mode1D(a)
#     475     def _mode1D(a):
#     476         vals, cnts = np.unique(a, return_counts=True)
# --> 477         return vals[cnts.argmax()], cnts.max()
#     478
#     479     # np.apply_along_axis will convert the _mode1D tuples to a numpy array, casting types in the process
#
# KeyboardInterrupt:

# %%
from imblearn.under_sampling import OneSidedSelection #non funziona non si sa perche 
from imblearn.under_sampling import InstanceHardnessThreshold
oss = OneSidedSelection(sampling_strategy='majority')
X_res, y_res = oss.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()
# Out:
# Resampled dataset shape Counter({1: 2646, 0: 128})

# %% [markdown]
# ### RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=42)
X_res, y_res = rus.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 128, 1: 128})

# %%
print(len(X_res),len(X_test))
# Out:
# 256 1470

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.7020408163265306
# F1-score [0.19188192 0.81734779]
#               precision    recall  f1-score   support
#
#            0       0.11      0.95      0.19        55
#            1       1.00      0.69      0.82      1415
#
#     accuracy                           0.70      1470
#    macro avg       0.55      0.82      0.50      1470
# weighted avg       0.96      0.70      0.79      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.7925170068027211
# F1-score [0.25061425 0.87958942]
#               precision    recall  f1-score   support
#
#            0       0.14      0.93      0.25        55
#            1       1.00      0.79      0.88      1415
#
#     accuracy                           0.79      1470
#    macro avg       0.57      0.86      0.57      1470
# weighted avg       0.96      0.79      0.86      1470

# %%
from sklearn.model_selection import cross_val_score
clf = RandomForestClassifier()
scores = cross_val_score(clf, X_res, y_res, cv=5)

print('Accuracy %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Accuracy 0.840 +/- 0.058

# %%
# Author: Noel Dawe <noel.dawe@gmail.com>
#
# License: BSD 3 clause
X=X_pca
y=y_res
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_gaussian_quantiles



# Create and fit an AdaBoosted decision tree
bdt = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

bdt.fit(X, y)

plot_colors = "br"
plot_step = 10
class_names = "AB"

plt.figure(figsize=(10, 5))

# Plot the decision boundaries
plt.subplot(121)
x_min, x_max = X[:, 0].min()-1 , X[:, 0].max()+1 
y_min, y_max = X[:, 1].min() -1, X[:, 1].max() +1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))

Z = bdt.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis("tight")

# Plot the training points
for i, n, c in zip(range(2), class_names, plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1],
                c=c, cmap=plt.cm.Paired,
                s=20, edgecolor='k',
                label="Class %s" % n)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Decision Boundary')

# Plot the two-class decision scores
twoclass_output = bdt.decision_function(X)
plot_range = (twoclass_output.min(), twoclass_output.max())
plt.subplot(122)
for i, n, c in zip(range(2), class_names, plot_colors):
    plt.hist(twoclass_output[y == i],
             bins=10,
             range=plot_range,
             facecolor=c,
             label='Class %s' % n,
             alpha=.5,
             edgecolor='k')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, y1, y2 * 1.2))
plt.legend(loc='upper right')
plt.ylabel('Samples')
plt.xlabel('Score')
plt.title('Decision Scores')

plt.tight_layout()
plt.subplots_adjust(wspace=0.35)
plt.show()

# %% [markdown]
# ### CondensedNearestNeighbour

# %%
import warnings
warnings.simplefilter("ignore")

# %%
cnn = CondensedNearestNeighbour(random_state=42, n_jobs=10)
X_res, y_res = cnn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-43611f823af0> in <module>
#       1 cnn = CondensedNearestNeighbour(random_state=42, n_jobs=10)
# ----> 2 X_res, y_res = cnn.fit_resample(X_train, y_train)
#       3 print('Resampled dataset shape %s' % Counter(y_res))
#       4 pca = PCA(n_components=2)
#       5 pca.fit(X_train)
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      81         )
#      82
# ---> 83         output = self._fit_resample(X, y)
#      84
#      85         y_ = (label_binarize(output[1], np.unique(y))
#
# ~\Anaconda3\lib\site-packages\imblearn\under_sampling\_prototype_selection\_condensed_nearest_neighbour.py in _fit_resample(self, X, y)
#     196                         # Classify all the element in S and avoid to test the
#     197                         # well classified elements
# --> 198                         pred_S_y = self.estimator_.predict(S_x)
#     199                         good_classif_label = np.unique(
#     200                             np.append(
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     185         for k, classes_k in enumerate(classes_):
#     186             if weights is None:
# --> 187                 mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#     188             else:
#     189                 mode, _ = weighted_mode(_y[neigh_ind, k], weights, axis=1)
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in mode(a, axis, nan_policy)
#     487     counts = np.zeros(a_view.shape[:-1], dtype=np.int)
#     488     for ind in inds:
# --> 489         modes[ind], counts[ind] = _mode1D(a_view[ind])
#     490     newshape = list(a.shape)
#     491     newshape[axis] = 1
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in _mode1D(a)
#     474
#     475     def _mode1D(a):
# --> 476         vals, cnts = np.unique(a, return_counts=True)
#     477         return vals[cnts.argmax()], cnts.max()
#     478
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     261     ar = np.asanyarray(ar)
#     262     if axis is None:
# --> 263         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     264         return _unpack_tuple(ret)
#     265
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     324         ret += (inv_idx,)
#     325     if return_counts:
# --> 326         idx = np.concatenate(np.nonzero(mask) + ([mask.size],))
#     327         ret += (np.diff(idx),)
#     328     return ret
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier

estimators = [('rf',RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)),
                             ('svr', make_pipeline(StandardScaler(), LinearSVC(random_state=42)))]
clf = StackingClassifier( estimators=estimators, final_estimator=MLPClassifier(random_state=0,solver= 'adam', learning_rate_init= 0.01, hidden_layer_sizes=(15)))

clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100), n_estimators=100, random_state=0)

clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %% [markdown]
# ## TomekLink

# %%
from imblearn.under_sampling import TomekLinks
tl = TomekLinks()
X_res, y_res = cnn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()
# Out:
# Resampled dataset shape Counter({1: 300, 0: 128})

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.8421768707482993
# F1-score [0.22666667 0.91212121]
#               precision    recall  f1-score   support
#
#            0       0.14      0.62      0.23        55
#            1       0.98      0.85      0.91      1415
#
#     accuracy                           0.84      1470
#    macro avg       0.56      0.73      0.57      1470
# weighted avg       0.95      0.84      0.89      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9761904761904762
# F1-score [0.58823529 0.98774081]
#               precision    recall  f1-score   support
#
#            0       0.83      0.45      0.59        55
#            1       0.98      1.00      0.99      1415
#
#     accuracy                           0.98      1470
#    macro avg       0.91      0.73      0.79      1470
# weighted avg       0.97      0.98      0.97      1470

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
X_test_pca = pca.transform(X_test)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100), n_estimators=100, random_state=0)

clf.fit(X_pca, y_res)

y_pred = clf.predict(X_test_pca)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test_pca)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9585034013605442
# F1-score [0.3960396  0.97851356]
#               precision    recall  f1-score   support
#
#            0       0.43      0.36      0.40        55
#            1       0.98      0.98      0.98      1415
#
#     accuracy                           0.96      1470
#    macro avg       0.71      0.67      0.69      1470
# weighted avg       0.96      0.96      0.96      1470

# %%
# Author: Noel Dawe <noel.dawe@gmail.com>
#
# License: BSD 3 clause
X=X_pca
y=y_res
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_gaussian_quantiles



# Create and fit an AdaBoosted decision tree
bdt = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

bdt.fit(X, y)

plot_colors = "br"
plot_step = 10
class_names = "AB"

plt.figure(figsize=(10, 5))

# Plot the decision boundaries
plt.subplot(121)
x_min, x_max = X[:, 0].min()-1 , X[:, 0].max()+1 
y_min, y_max = X[:, 1].min() -1, X[:, 1].max() +1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))

Z = bdt.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis("tight")

# Plot the training points
for i, n, c in zip(range(2), class_names, plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1],
                c=c, cmap=plt.cm.Paired,
                s=20, edgecolor='k',
                label="Class %s" % n)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Decision Boundary')

# Plot the two-class decision scores
twoclass_output = bdt.decision_function(X)
plot_range = (twoclass_output.min(), twoclass_output.max())
plt.subplot(122)
for i, n, c in zip(range(2), class_names, plot_colors):
    plt.hist(twoclass_output[y == i],
             bins=10,
             range=plot_range,
             facecolor=c,
             label='Class %s' % n,
             alpha=.5,
             edgecolor='k')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, y1, y2 * 1.2))
plt.legend(loc='upper right')
plt.ylabel('Samples')
plt.xlabel('Score')
plt.title('Decision Scores')

plt.tight_layout()
plt.subplots_adjust(wspace=0.35)
plt.show()

# %% [markdown]
# # Oversampling

# %%
fig, axes = plt.subplots(1, 4, figsize=(20,3))

from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_res, y_res = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[0].set_title('Random Oversample')

from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[1].set_title('SMOTE')

from imblearn.over_sampling import ADASYN
adasyn  = ADASYN(random_state=42)
X_res, y_res = adasyn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[2].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[2].set_title('ADASYN')

from imblearn.over_sampling import SVMSMOTE
svm  =SVMSMOTE()
X_res, y_res = ksm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)
axes[3].scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
axes[3].set_title('SVMSMOTE')

plt.show()
# Out:
# Resampled dataset shape Counter({1: 3302, 0: 3302})
# Resampled dataset shape Counter({1: 3302, 0: 3302})
# Resampled dataset shape Counter({1: 3302, 0: 3285})
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4c2ae21b92d5> in <module>
#      33 from imblearn.over_sampling import SVMSMOTE
#      34 svm  =SVMSMOTE()
# ---> 35 X_res, y_res = ksm.fit_resample(X_train, y_train)
#      36 print('Resampled dataset shape %s' % Counter(y_res))
#      37 pca = PCA(n_components=2)
#
# NameError: name 'ksm' is not defined

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ### RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42, sampling_strategy = 'minority')
X_res, y_res = ros.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({1: 3302, 0: 3302})

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9680272108843537
# F1-score [0.60504202 0.98333924]
#               precision    recall  f1-score   support
#
#            0       0.56      0.65      0.61        55
#            1       0.99      0.98      0.98      1415
#
#     accuracy                           0.97      1470
#    macro avg       0.77      0.82      0.79      1470
# weighted avg       0.97      0.97      0.97      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9727891156462585
# F1-score [0.65517241 0.98583569]
#               precision    recall  f1-score   support
#
#            0       0.62      0.69      0.66        55
#            1       0.99      0.98      0.99      1415
#
#     accuracy                           0.97      1470
#    macro avg       0.81      0.84      0.82      1470
# weighted avg       0.97      0.97      0.97      1470

# %%
import pydotplus
from sklearn import tree
from IPython.display import Image

# %%
dot_data = tree.export_graphviz(clf.estimators_[0], out_file=None,  
                                feature_names=attributes, 
                                class_names=['Empty', 'Occupied'],  
                                filled=True, rounded=True,  
                                special_characters=True, max_depth=4)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-39-29529196637b> in <module>
#       5                                 special_characters=True, max_depth=4)
#       6 graph = pydotplus.graph_from_dot_data(dot_data)
# ----> 7 Image(graph.create_png())
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in <lambda>(f, prog)
#    1795             self.__setattr__(
#    1796                 'create_' + frmt,
# -> 1797                 lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798             )
#    1799             f = self.__dict__['create_' + frmt]
#
# ~\Anaconda3\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier

estimators = [('rf',RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)),
                             ('svr', make_pipeline(StandardScaler(), LinearSVC(random_state=42)))]
clf = StackingClassifier( estimators=estimators, final_estimator=MLPClassifier(random_state=0,solver= 'adam', learning_rate_init= 0.01, hidden_layer_sizes=(15)))

clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()

# %%
dot_data = tree.export_graphviz(clf.estimators_[0], out_file=None,  
                                feature_names=attributes, 
                                class_names=['Empty', 'Occupied'],  
                                filled=True, rounded=True,  
                                special_characters=True, max_depth=4)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-161-29529196637b> in <module>
#       3                                 class_names=['Empty', 'Occupied'],
#       4                                 filled=True, rounded=True,
# ----> 5                                 special_characters=True, max_depth=4)
#       6 graph = pydotplus.graph_from_dot_data(dot_data)
#       7 Image(graph.create_png())
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export_graphviz(decision_tree, out_file, max_depth, feature_names, class_names, label, filled, leaves_parallel, impurity, node_ids, proportion, rotate, rounded, special_characters, precision)
#     762             rounded=rounded, special_characters=special_characters,
#     763             precision=precision)
# --> 764         exporter.export(decision_tree)
#     765
#     766         if return_string:
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree)
#     404             self.recurse(decision_tree, 0, criterion="impurity")
#     405         else:
# --> 406             self.recurse(decision_tree.tree_, 0,
#     407                          criterion=decision_tree.criterion)
#     408
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'tree_'

# %%
pca = PCA(n_components=2 )
pca.fit(X_train)
X_pca = pca.transform(X_res)
X_test_pca = pca.transform(X_test)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
pd.Series(y_res).value_counts()
# Out:
# 1    3302
# 0    3302
# dtype: int64

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100), n_estimators=100, random_state=0)

clf.fit(X_pca, y_res)

y_pred = clf.predict(X_test_pca)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test_pca)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.8829931972789116
# F1-score [0.2892562  0.93624907]
#               precision    recall  f1-score   support
#
#            0       0.19      0.64      0.29        55
#            1       0.98      0.89      0.94      1415
#
#     accuracy                           0.88      1470
#    macro avg       0.59      0.76      0.61      1470
# weighted avg       0.95      0.88      0.91      1470

# %%
# Author: Noel Dawe <noel.dawe@gmail.com>
#
# License: BSD 3 clause
X=X_pca
y=y_res
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_gaussian_quantiles



# Create and fit an AdaBoosted decision tree
bdt = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                         algorithm="SAMME",
                         n_estimators=200)

bdt.fit(X_pca, y_res)

plot_colors = "br"
plot_step = 10
class_names = "AB"

plt.figure(figsize=(10, 5))

# Plot the decision boundaries
plt.subplot(121)
x_min, x_max = X[:, 0].min()-1 , X[:, 0].max()+1 
y_min, y_max = X[:, 1].min() -1, X[:, 1].max() +1
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))

Z = bdt.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis("tight")

# Plot the training points
for i, n, c in zip(range(2), class_names, plot_colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1],
                c=c, cmap=plt.cm.Paired,
                s=20, edgecolor='k',
                label="Class %s" % n)
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.legend(loc='upper right')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Decision Boundary')

# Plot the two-class decision scores
twoclass_output = bdt.decision_function(X)
plot_range = (twoclass_output.min(), twoclass_output.max())
plt.subplot(122)
for i, n, c in zip(range(2), class_names, plot_colors):
    plt.hist(twoclass_output[y == i],
             bins=10,
             range=plot_range,
             facecolor=c,
             label='Class %s' % n,
             alpha=.5,
             edgecolor='k')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, y1, y2 * 1.2))
plt.legend(loc='upper right')
plt.ylabel('Samples')
plt.xlabel('Score')
plt.title('Decision Scores')

plt.tight_layout()
plt.subplots_adjust(wspace=0.35)
plt.show()

# %% [markdown]
# ### SMOTE

# %%
svm = SVMSMOTE(random_state=42)
X_res, y_res = svm.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({1: 3302, 0: 3302})

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9523809523809523
# F1-score [0.50704225 0.97498213]
#               precision    recall  f1-score   support
#
#            0       0.41      0.65      0.51        55
#            1       0.99      0.96      0.97      1415
#
#     accuracy                           0.95      1470
#    macro avg       0.70      0.81      0.74      1470
# weighted avg       0.96      0.95      0.96      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9755102040816327
# F1-score [0.67857143 0.98727016]
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68        55
#            1       0.99      0.99      0.99      1415
#
#     accuracy                           0.98      1470
#    macro avg       0.83      0.84      0.83      1470
# weighted avg       0.98      0.98      0.98      1470

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100), n_estimators=100, random_state=0)

clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
# Out:
# Accuracy 0.9673469387755103
# F1-score [0.61290323 0.98295455]
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61        55
#            1       0.99      0.98      0.98      1415
#
#     accuracy                           0.97      1470
#    macro avg       0.77      0.83      0.80      1470
# weighted avg       0.97      0.97      0.97      1470

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from sklearn.neural_network import MLPClassifier

estimators = [('rf',RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=3, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)),
                             ('svr', make_pipeline(StandardScaler(), LinearSVC(random_state=42)))]
final_estimator=MLPClassifier(random_state=0,solver= 'adam', learning_rate_init= 0.01, hidden_layer_sizes=(5))
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
# Out:
# Accuracy 0.9585034013605442
# F1-score [0.57342657 0.97819092]
#               precision    recall  f1-score   support
#
#            0       0.47      0.75      0.57        55
#            1       0.99      0.97      0.98      1415
#
#     accuracy                           0.96      1470
#    macro avg       0.73      0.86      0.78      1470
# weighted avg       0.97      0.96      0.96      1470

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN
adasyn  = ADASYN(random_state=42)
X_res, y_res = adasyn.fit_resample(X_train, y_train)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({1: 3302, 0: 3285})

# %%
pca = PCA(n_components=2)
pca.fit(X_train)
X_pca = pca.transform(X_res)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_res, cmap=plt.cm.prism, edgecolor='k', alpha=0.7)
plt.show()

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9401360544217687
# F1-score [0.39726027 0.96850394]
#               precision    recall  f1-score   support
#
#            0       0.32      0.53      0.40        55
#            1       0.98      0.96      0.97      1415
#
#     accuracy                           0.94      1470
#    macro avg       0.65      0.74      0.68      1470
# weighted avg       0.96      0.94      0.95      1470

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, 
                             min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', random_state=0)
clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9666666666666667
# F1-score [0.60162602 0.98260561]
#               precision    recall  f1-score   support
#
#            0       0.54      0.67      0.60        55
#            1       0.99      0.98      0.98      1415
#
#     accuracy                           0.97      1470
#    macro avg       0.77      0.83      0.79      1470
# weighted avg       0.97      0.97      0.97      1470

# %%
dot_data = tree.export_graphviz(clf.estimators_[0], out_file=None,  
                                feature_names=attributes, 
                                class_names=['Empty','Occupied'],  
                                filled=True, rounded=True,  
                                special_characters=True, max_depth=4)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100), n_estimators=100, random_state=0)

clf.fit(X_res, y_res)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9673469387755103
# F1-score [0.61290323 0.98295455]
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61        55
#            1       0.99      0.98      0.98      1415
#
#     accuracy                           0.97      1470
#    macro avg       0.77      0.83      0.80      1470
# weighted avg       0.97      0.97      0.97      1470

# %% [markdown]
# # Class Weight

# %%
clf = DecisionTreeClassifier(min_samples_leaf=3, class_weight={0:19, 1: 1}, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# Accuracy 0.9416157501697217
# F1-score [0.43421053 0.96921976]
#               precision    recall  f1-score   support
#
#            0       0.34      0.60      0.43        55
#            1       0.98      0.95      0.97      1418
#
#     accuracy                           0.94      1473
#    macro avg       0.66      0.78      0.70      1473
# weighted avg       0.96      0.94      0.95      1473

# %%
X=X_train
y=y_train
import pandas as pd
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score 
from sklearn.datasets import make_classification
from sklearn.naive_bayes import GaussianNB
RNG = 42
# Make some synthetic imbalanced binary classification data
X, y = make_classification(n_classes=2, class_sep=2, 
    weights=[0.97, 0.03], 
    n_informative=2, n_redundant=5, 
    flip_y=0.05, n_features=50, 
    n_clusters_per_class=1, 
    n_samples=1000, random_state=RNG)

metric_names = ['f1', 'roc_auc', 'average_precision', 'accuracy', 'precision', 'recall']
scores_df = pd.DataFrame(index=metric_names, columns=['Random-CV', 'Stratified-CV']) # to store the scores
cv = KFold(n_splits=3)
scv = StratifiedKFold(n_splits=3)
clf = RandomForestClassifier()
for metric in metric_names:
    score1 = cross_val_score(clf, X, y, scoring=metric, cv=cv).mean()
    score2 = cross_val_score(clf, X, y, scoring=metric, cv=scv).mean()
    scores_df.loc[metric] = [score1, score2]

# %%
print(scores_df.T)
# Out:
#                      f1   roc_auc average_precision  accuracy precision  \
# Random-CV      0.676363  0.734749          0.582429  0.974993  0.952381
# Stratified-CV  0.702564  0.752885          0.581961  0.972991   0.87963
#
#                  recall
# Random-CV      0.546366
# Stratified-CV  0.555556

# %%
scores_df
# Out:
#                   Random-CV Stratified-CV
# f1                 0.676363      0.702564
# roc_auc            0.734749      0.752885
# average_precision  0.582429      0.581961
# accuracy           0.974993      0.972991
# precision          0.952381       0.87963
# recall             0.546366      0.555556

# %% [markdown]
# # Meta-Cost Sensitive Classifier

# %%
from costcla.models import CostSensitiveDecisionTreeClassifier
from costcla.metrics import savings_score

# %% [markdown]
# cost_mat : array-like of shape = [n_samples, 4]
#
# Cost matrix of the classification problem Where the columns represents the costs of: false positives, false negatives, true positives and true negatives, for each example.

# %%
attributes = ['Temperature', 'Humidity', 'Light', 'CO2']

X_train =training[attributes].copy()
y_train=training[['Occupancy']].values
X_test=test[attributes].copy()
y_test=test[['Occupancy']].values

# %%
cost = [1, 10, 1, 1]
cost_mat = np.array([cost] * len(X_train))
cost_mat.shape
# Out:
# (3434, 4)

# %%
cost_mat
# Out:
# array([[ 1, 10,  1,  1],
#        [ 1, 10,  1,  1],
#        [ 1, 10,  1,  1],
#        ...,
#        [ 1, 10,  1,  1],
#        [ 1, 10,  1,  1],
#        [ 1, 10,  1,  1]])

# %%
cost = [1, 10, 1, 1]
cost = np.array(cost)

# %%
y_train.shape
# Out:
# (3434, 1)

# %%
clf = CostSensitiveDecisionTreeClassifier()
clf.fit(X_train, y_train, cost)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

y_score = clf.predict_proba(X_test)
fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr0, tpr0, color='darkorange', lw=3, label='$AUC_0$ = %.3f' % (roc_auc0))
plt.plot(fpr, tpr, color='green', lw=3, label='$AUC_1$ = %.3f' % (roc_auc))

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('ROC curve', fontsize=16)
plt.legend(loc="lower right", fontsize=14, frameon=False)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-226-80091ff1ef7f> in <module>
#       1 clf = CostSensitiveDecisionTreeClassifier()
# ----> 2 clf.fit(X_train, y_train, cost)
#       3
#       4 y_pred = clf.predict(X_test)
#       5
#
# ~\Anaconda3\lib\site-packages\costcla\models\cost_tree.py in fit(self, X, y, cost_mat, check_input)
#     433         self.max_features_ = max_features
#     434
# --> 435         self.tree_.tree = self._tree_grow(y, X, cost_mat)
#     436
#     437         if self.pruned:
#
# ~\Anaconda3\lib\site-packages\costcla\models\cost_tree.py in _tree_grow(self, y_true, X, cost_mat, level)
#     332
#     333         # Calculate the best split of the current node
# --> 334         split, gain, Xl_pred, y_pred, y_prob = self._best_split(y_true, X, cost_mat)
#     335
#     336         n_samples, n_features = X.shape
#
# ~\Anaconda3\lib\site-packages\costcla\models\cost_tree.py in _best_split(self, y_true, X, cost_mat)
#     268         num_pct = self.num_pct
#     269
# --> 270         cost_base, y_pred, y_prob = self._node_cost(y_true, cost_mat)
#     271
#     272         # Calculate the gain of all features each split in num_pct
#
# ~\Anaconda3\lib\site-packages\costcla\models\cost_tree.py in _node_cost(self, y_true, cost_mat)
#     158         # Evaluates the cost by predicting the node as positive and negative
#     159         costs = np.zeros(2)
# --> 160         costs[0] = cost_loss(y_true, np.zeros(y_true.shape), cost_mat)
#     161         costs[1] = cost_loss(y_true, np.ones(y_true.shape), cost_mat)
#     162
#
# ~\Anaconda3\lib\site-packages\costcla\metrics\costs.py in cost_loss(y_true, y_pred, cost_mat)
#      77     y_pred = column_or_1d(y_pred)
#      78     y_pred = (y_pred == 1).astype(np.float)
# ---> 79     cost = y_true * ((1 - y_pred) * cost_mat[:, 1] + y_pred * cost_mat[:, 2])
#      80     cost += (1 - y_true) * (y_pred * cost_mat[:, 0] + (1 - y_pred) * cost_mat[:, 3])
#      81     return np.sum(cost)
#
# IndexError: too many indices for array

# %%
cost_mat_test = np.array([cost] * len(X_test))
print(savings_score(y_test, y_pred, cost_mat_test))
print(savings_score(y_test, y_pred0, cost_mat_test))
# Out:
# 0.17333333333333334
# 0.22666666666666668

# %% [markdown]
# # Scikit-plot

# %%
from scikitplot.metrics import plot_roc
from scikitplot.metrics import plot_precision_recall
from scikitplot.metrics import plot_cumulative_gain
from scikitplot.metrics import plot_lift_curve

# %%
attributes = [col for col in df.columns if col != class_name]
X = df[attributes].values
y = df[class_name]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

clf = DecisionTreeClassifier(min_samples_leaf=3, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
y_score = clf.predict_proba(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.932
# F1-score [0.96046512 0.75714286]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       855
#            1       0.79      0.73      0.76       145
#
#     accuracy                           0.93      1000
#    macro avg       0.87      0.85      0.86      1000
# weighted avg       0.93      0.93      0.93      1000

# %%
plot_roc(y_test, y_score)
plt.show()

# %%
plot_precision_recall(y_test, y_score)
plt.show()

# %%
plot_cumulative_gain(y_test, y_score)
plt.show()

# %%
plot_lift_curve(y_test, y_score)
plt.show()
