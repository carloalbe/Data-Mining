# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from collections import defaultdict
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
#plt.rcParams['figure.dpi']= 300  #resolution

from collections import defaultdict

# %%
def draw_list(ts_list, attribute, ts_number=1000, time = None , formatter = None):
    if ts_number >= len(ts_list): ts_number = len(ts_list)-1
    fig = plt.figure()
    ax = fig.subplots()
    for ts in ts_list[:ts_number]:
        if time == None: index = list(ts.index.values)
        else: index= ts[time]
        ax.plot(index, ts[attribute])
    ax.set_ylabel(attribute)
    if formatter !=None:
        date_form = DateFormatter(formatter)
        ax.xaxis.set_major_formatter(date_form)
    plt.show()

# %% [markdown]
# # Data Preparation

# %%
time_col = 'date'

attributes = ['date', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy','Weekday']


df=pd.read_csv(r'../../data/datatraining.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon1=df[df['Weekday']==0][attributes].copy()
tue1=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed1=df[df['Weekday']==2][attributes].copy() #incompleted too
thu1=df[df['Weekday']==3][attributes].copy()
fri1=df[df['Weekday']==4][attributes].copy()
sat1=df[df['Weekday']==5][attributes].copy()
sun1=df[df['Weekday']==6][attributes].copy()
    
weekdays1 = [thu1,fri1,sat1,sun1,mon1] #I dont want incompleted days, so wednesday and tuesday are excluded



df=pd.read_csv(r'../../data/datatest2.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())
                                 
mon2=df[df['Weekday']==0][attributes].copy()
tue2=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed2=df[df['Weekday']==2][attributes].copy() #incompleted too
thu2=df[df['Weekday']==3][attributes].copy()
fri2=df[df['Weekday']==4][attributes].copy()
sat2=df[df['Weekday']==5][attributes].copy()
sun2=df[df['Weekday']==6][attributes].copy()
    
weekdays2 = [thu2,fri2,sat2,sun2,mon2] #I dont want incompleted days, so wednesday and tuesday are excluded

# %% [markdown]
# ## week list

# %%
week_size = 144
week_list = []

week1 = pd.DataFrame()
for day in weekdays1:
    day.sort_values(time_col, inplace=True)#first of all: order
    week1 = week1.append(day, ignore_index=True )    ##a week

week1_list = []
tmp = week1.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week1_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
week2 = pd.DataFrame()
for day in weekdays2:    
    day.sort_values(time_col, inplace=True)#first of all: order
    week2 = week2.append(day, ignore_index=True)    ##a week
    
week2_list = []
tmp = week2.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week2_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
random.shuffle(week_list)
draw_list(week_list, 'Temperature', 15, time = time_col ,formatter = '%d')
# Out:
# C:\Users\carlo\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## day_list

# %%
day_list = []
day_size = 120

day1_list=[]
for day in weekdays1:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day1_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extra


day2_list = []
for day in weekdays2:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day2_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extract


draw_list(day_list, 'Temperature', time = 'time', formatter = '%H')

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_list:
    ts = temp['CO2'].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_list[1])
for ts in ts_list:
    ts_array.append(np.array(ts).reshape(ts_size,))
    
X = np.array(ts_array)

weekend = lambda ts: 'Weekday' if int(ts['Weekday'][ts.index[0]])< 5 else 'Holiday' 
labels = np.array([weekend(ts) for ts in day_list ])

y = preprocessing.LabelEncoder().fit_transform(labels)
plt.figure()
for i, classe in enumerate(['Weekday','Holiday']):
    plt.subplot(2, 1, i + 1)
    for x in X[labels == classe][:10]:
        plt.plot(x, color='C'+str(i), linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

#plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()

# %% [markdown]
# # Data Normalization

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

from tslearn.preprocessing import TimeSeriesScalerMinMax

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score
# Out:
# Using Theano backend.
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
scaler = TimeSeriesScalerMinMax()
X = scaler.fit_transform(X).reshape(X.shape[0], X.shape[1])

# %% [markdown]
# # Data Partitioning

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %% [markdown]
# # Shaplet Classifier

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 84
# ts_sz 120
# n_classes 2
# shapelet_sizes {12: 3}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        max_iter=200,
                        verbose=1)

# %%
shp_clf.fit(X_train, y_train)
# Out:
# Epoch 1/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6850 - binary_accuracy: 0.4048 - binary_crossentropy: 0.6850
# Epoch 2/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6849 - binary_accuracy: 0.4048 - binary_crossentropy: 0.6849
# Epoch 3/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6848 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6848
# Epoch 4/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6847 - binary_accuracy: 0.7976 - binary_crossentropy: 0.6847
# Epoch 5/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6846 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6846
# Epoch 6/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6845 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6845
# Epoch 7/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6844 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6844
# Epoch 8/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6843 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6843
# Epoch 9/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6842 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6842
# Epoch 10/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6841 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6841
# Epoch 11/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6840 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6840
# Epoch 12/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6839 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6839
# Epoch 13/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6838 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6838
# Epoch 14/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6837 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6837
# Epoch 15/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6836 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6836
# Epoch 16/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6835 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6835
# Epoch 17/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6834 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6834
# Epoch 18/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6833 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6833
# Epoch 19/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6832 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6832
# Epoch 20/200
# 84/84 [==============================] - 0s 321us/step - loss: 0.6831 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6831
# Epoch 21/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6831 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6831
# Epoch 22/200
# 84/84 [==============================] - 0s 488us/step - loss: 0.6830 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6830
# Epoch 23/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6829 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6829
# Epoch 24/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6828 - binary_accuracy: 0.9048 - binary_crossentropy: 0.6828
# Epoch 25/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6827 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6827
# Epoch 26/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6826 - binary_accuracy: 0.8929 - binary_crossentropy: 0.6826
# Epoch 27/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6825 - binary_accuracy: 0.8810 - binary_crossentropy: 0.6825
# Epoch 28/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6824 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6824
# Epoch 29/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6823 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6823
# Epoch 30/200
# 84/84 [==============================] - 0s 417us/step - loss: 0.6822 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6822
# Epoch 31/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6821 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6821
# Epoch 32/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6820 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6820
# Epoch 33/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6820 - binary_accuracy: 0.8690 - binary_crossentropy: 0.6820
# Epoch 34/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6819 - binary_accuracy: 0.8571 - binary_crossentropy: 0.6819
# Epoch 35/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6818 - binary_accuracy: 0.8452 - binary_crossentropy: 0.6818
# Epoch 36/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6817 - binary_accuracy: 0.8452 - binary_crossentropy: 0.6817
# Epoch 37/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6816 - binary_accuracy: 0.8452 - binary_crossentropy: 0.6816
# Epoch 38/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6815 - binary_accuracy: 0.8333 - binary_crossentropy: 0.6815
# Epoch 39/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6814 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6814
# Epoch 40/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6814 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6814
# Epoch 41/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6813 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6813
# Epoch 42/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6812 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6812
# Epoch 43/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6811 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6811
# Epoch 44/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6810 - binary_accuracy: 0.8214 - binary_crossentropy: 0.6810
# Epoch 45/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6809 - binary_accuracy: 0.8095 - binary_crossentropy: 0.6809
# Epoch 46/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6808 - binary_accuracy: 0.7976 - binary_crossentropy: 0.6808
# Epoch 47/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6808 - binary_accuracy: 0.7976 - binary_crossentropy: 0.6808
# Epoch 48/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6807 - binary_accuracy: 0.7857 - binary_crossentropy: 0.6807
# Epoch 49/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6806 - binary_accuracy: 0.7857 - binary_crossentropy: 0.6806
# Epoch 50/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6805 - binary_accuracy: 0.7738 - binary_crossentropy: 0.6805
# Epoch 51/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6804 - binary_accuracy: 0.7619 - binary_crossentropy: 0.6804
# Epoch 52/200
# 84/84 [==============================] - 0s 297us/step - loss: 0.6804 - binary_accuracy: 0.7619 - binary_crossentropy: 0.6804
# Epoch 53/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6803 - binary_accuracy: 0.7619 - binary_crossentropy: 0.6803
# Epoch 54/200
# 84/84 [==============================] - 0s 298us/step - loss: 0.6802 - binary_accuracy: 0.7500 - binary_crossentropy: 0.6802
# Epoch 55/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6801 - binary_accuracy: 0.7381 - binary_crossentropy: 0.6801
# Epoch 56/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6800 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6800
# Epoch 57/200
# 84/84 [==============================] - 0s 417us/step - loss: 0.6800 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6800
# Epoch 58/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6799 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6799
# Epoch 59/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6798 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6798
# Epoch 60/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6797 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6797
# Epoch 61/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6796 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6796
# Epoch 62/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6796 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6796
# Epoch 63/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6795 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6795
# Epoch 64/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6794 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6794
# Epoch 65/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6793 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6793
# Epoch 66/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6793 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6793
# Epoch 67/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6792 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6792
# Epoch 68/200
# 84/84 [==============================] - 0s 369us/step - loss: 0.6791 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6791
# Epoch 69/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6790 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6790
# Epoch 70/200
# 84/84 [==============================] - 0s 417us/step - loss: 0.6790 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6790
# Epoch 71/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6789 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6789
# Epoch 72/200
# 84/84 [==============================] - 0s 310us/step - loss: 0.6788 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6788
# Epoch 73/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6787 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6787
# Epoch 74/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6787 - binary_accuracy: 0.7262 - binary_crossentropy: 0.6787
# Epoch 75/200
# 84/84 [==============================] - 0s 262us/step - loss: 0.6786 - binary_accuracy: 0.7143 - binary_crossentropy: 0.6786
# Epoch 76/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6785 - binary_accuracy: 0.7143 - binary_crossentropy: 0.6785
# Epoch 77/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6785 - binary_accuracy: 0.7143 - binary_crossentropy: 0.6785
# Epoch 78/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6784 - binary_accuracy: 0.7143 - binary_crossentropy: 0.6784
# Epoch 79/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6783 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6783
# Epoch 80/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6782 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6782
# Epoch 81/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6782 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6782
# Epoch 82/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6781 - binary_accuracy: 0.7024 - binary_crossentropy: 0.6781
# Epoch 83/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6780 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6780
# Epoch 84/200
# 84/84 [==============================] - 0s 381us/step - loss: 0.6780 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6780
# Epoch 85/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6779 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6779
# Epoch 86/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6778 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6778
# Epoch 87/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6778 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6778
# Epoch 88/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6777 - binary_accuracy: 0.6905 - binary_crossentropy: 0.6777
# Epoch 89/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6776 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6776
# Epoch 90/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6776 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6776
# Epoch 91/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6775 - binary_accuracy: 0.6786 - binary_crossentropy: 0.6775
# Epoch 92/200
# 84/84 [==============================] - 0s 345us/step - loss: 0.6774 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6774
# Epoch 93/200
# 84/84 [==============================] - 0s 321us/step - loss: 0.6774 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6774
# Epoch 94/200
# 84/84 [==============================] - 0s 393us/step - loss: 0.6773 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6773
# Epoch 95/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6772 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6772
# Epoch 96/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6772 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6772
# Epoch 97/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6771 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6771
# Epoch 98/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6770 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6770
# Epoch 99/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6770 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6770
# Epoch 100/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6769 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6769
# Epoch 101/200
# 84/84 [==============================] - 0s 203us/step - loss: 0.6768 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6768
# Epoch 102/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6768 - binary_accuracy: 0.6429 - binary_crossentropy: 0.6768
# Epoch 103/200
# 84/84 [==============================] - 0s 262us/step - loss: 0.6767 - binary_accuracy: 0.6310 - binary_crossentropy: 0.6767
# Epoch 104/200
# 84/84 [==============================] - 0s 298us/step - loss: 0.6766 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6766
# Epoch 105/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6766 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6766
# Epoch 106/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6765 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6765
# Epoch 107/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6765 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6765
# Epoch 108/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6764 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6764
# Epoch 109/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6763 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6763
# Epoch 110/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6763 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6763
# Epoch 111/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6762 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6762
# Epoch 112/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6761 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6761
# Epoch 113/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6761 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6761
# Epoch 114/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6760 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6760
# Epoch 115/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6760 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6760
# Epoch 116/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6759 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6759
# Epoch 117/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6758 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6758
# Epoch 118/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6758 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6758
# Epoch 119/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6757 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6757
# Epoch 120/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6757 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6757
# Epoch 121/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6756 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6756
# Epoch 122/200
# 84/84 [==============================] - 0s 262us/step - loss: 0.6756 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6756
# Epoch 123/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6755 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6755
# Epoch 124/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6754 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6754
# Epoch 125/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6754 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6754
# Epoch 126/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6753 - binary_accuracy: 0.6190 - binary_crossentropy: 0.6753
# Epoch 127/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6753 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6753
# Epoch 128/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6752 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6752
# Epoch 129/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6752 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6752
# Epoch 130/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6751 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6751
# Epoch 131/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6750 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6750
# Epoch 132/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6750 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6750
# Epoch 133/200
# 84/84 [==============================] - 0s 488us/step - loss: 0.6749 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6749
# Epoch 134/200
# 84/84 [==============================] - 0s 488us/step - loss: 0.6749 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6749
# Epoch 135/200
# 84/84 [==============================] - 0s 310us/step - loss: 0.6748 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6748
# Epoch 136/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6748 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6748
# Epoch 137/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6747 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6747
# Epoch 138/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6747 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6747
# Epoch 139/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6746 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6746
# Epoch 140/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6746 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6746
# Epoch 141/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6745 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6745
# Epoch 142/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6744 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6744
# Epoch 143/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6744 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6744
# Epoch 144/200
# 84/84 [==============================] - 0s 298us/step - loss: 0.6743 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6743
# Epoch 145/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6743 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6743
# Epoch 146/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6742 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6742
# Epoch 147/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6742 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6742
# Epoch 148/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6741 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6741
# Epoch 149/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6741 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6741
# Epoch 150/200
# 84/84 [==============================] - 0s 393us/step - loss: 0.6740 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6740
# Epoch 151/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6740 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6740
# Epoch 152/200
# 84/84 [==============================] - 0s 583us/step - loss: 0.6739 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6739
# Epoch 153/200
# 84/84 [==============================] - 0s 417us/step - loss: 0.6739 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6739
# Epoch 154/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6738 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6738
# Epoch 155/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6738 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6738
# Epoch 156/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6737 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6737
# Epoch 157/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6737 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6737
# Epoch 158/200
# 84/84 [==============================] - 0s 298us/step - loss: 0.6736 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6736
# Epoch 159/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6736 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6736
# Epoch 160/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6735 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6735
# Epoch 161/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6735 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6735
# Epoch 162/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6734 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6734
# Epoch 163/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6734 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6734
# Epoch 164/200
# 84/84 [==============================] - 0s 452us/step - loss: 0.6733 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6733
# Epoch 165/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6733 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6733
# Epoch 166/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6732 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6732
# Epoch 167/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6732 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6732
# Epoch 168/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6732 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6732
# Epoch 169/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6731 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6731
# Epoch 170/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6731 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6731
# Epoch 171/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6730 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6730
# Epoch 172/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6730 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6730
# Epoch 173/200
# 84/84 [==============================] - 0s 441us/step - loss: 0.6729 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6729
# Epoch 174/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6729 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6729
# Epoch 175/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6728 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6728
# Epoch 176/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6728 - binary_accuracy: 0.6071 - binary_crossentropy: 0.6728
# Epoch 177/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6727 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6727
# Epoch 178/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6727 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6727
# Epoch 179/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6727 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6727
# Epoch 180/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6726 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6726
# Epoch 181/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6726 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6726
# Epoch 182/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6725 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6725
# Epoch 183/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6725 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6725
# Epoch 184/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6724 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6724
# Epoch 185/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6724 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6724
# Epoch 186/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6723 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6723
# Epoch 187/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6723 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6723
# Epoch 188/200
# 84/84 [==============================] - 0s 321us/step - loss: 0.6723 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6723
# Epoch 189/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6722 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6722
# Epoch 190/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6722 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6722
# Epoch 191/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6721 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6721
# Epoch 192/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6721 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6721
# Epoch 193/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6720 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6720
# Epoch 194/200
# 84/84 [==============================] - 0s 345us/step - loss: 0.6720 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6720
# Epoch 195/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6720 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6720
# Epoch 196/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6719 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6719
# Epoch 197/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6719 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6719
# Epoch 198/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6718 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6718
# Epoch 199/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6718 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6718
# Epoch 200/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6718 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6718
# ShapeletModel(batch_size=256, max_iter=200, n_shapelets_per_size={12: 3},
#               optimizer='sgd', random_state=None, shapelet_length=0.15,
#               total_lengths=3, verbose=1, verbose_level=None,
#               weight_regularizer=0.0)

# %%
y_pred = shp_clf.predict(X_test)
# Out:
# 36/36 [==============================] - 0s 139us/step

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
# Out:
# 84/84 [==============================] - 0s 48us/step

# %%
X_train2.shape
# Out:
# (84, 3)

# %%
X_train2
# Out:
# array([[0.00060393, 0.00308574, 0.00239991],
#        [0.00126228, 0.00486099, 0.00280629],
#        [0.02983886, 0.04330793, 0.0397702 ],
#        [0.00033135, 0.00096462, 0.00092256],
#        [0.00223094, 0.00645574, 0.00515528],
#        [0.00049478, 0.00193538, 0.00098868],
#        [0.01001357, 0.0184252 , 0.01485856],
#        [0.0006262 , 0.00099949, 0.00104932],
#        [0.00091066, 0.00390715, 0.00297142],
#        [0.00028624, 0.00139568, 0.0010635 ],
#        [0.00078056, 0.00440018, 0.00278914],
#        [0.0003813 , 0.00134241, 0.00122299],
#        [0.00079819, 0.00365457, 0.00259915],
#        [0.052582  , 0.07210371, 0.06584111],
#        [0.03831352, 0.05481328, 0.04517832],
#        [0.00098223, 0.00443117, 0.00352754],
#        [0.00028146, 0.00108757, 0.00097597],
#        [0.02518452, 0.03747857, 0.0325971 ],
#        [0.00038252, 0.0010784 , 0.0009868 ],
#        [0.02999999, 0.04239419, 0.03754434],
#        [0.00060477, 0.00096753, 0.00101039],
#        [0.00033253, 0.00205086, 0.00176732],
#        [0.00053279, 0.00103107, 0.00101333],
#        [0.02315723, 0.03438269, 0.02847935],
#        [0.00069219, 0.00211992, 0.00162555],
#        [0.00041172, 0.00158784, 0.00113613],
#        [0.00054132, 0.00099871, 0.00104509],
#        [0.00748229, 0.01369813, 0.01356221],
#        [0.00054081, 0.00148202, 0.00132869],
#        [0.00030617, 0.00102274, 0.00095245],
#        [0.00053274, 0.00098829, 0.0010451 ],
#        [0.01385732, 0.02311432, 0.01773894],
#        [0.00034209, 0.00098897, 0.00089011],
#        [0.00041673, 0.00239232, 0.00155014],
#        [0.01477511, 0.02484424, 0.01951633],
#        [0.00028913, 0.0012663 , 0.00100204],
#        [0.00136506, 0.00582178, 0.0039878 ],
#        [0.00032702, 0.00172911, 0.0015452 ],
#        [0.00050159, 0.00252031, 0.00192485],
#        [0.00038889, 0.00102118, 0.00099784],
#        [0.00029048, 0.00130019, 0.00096352],
#        [0.00046429, 0.0029959 , 0.00189202],
#        [0.01410977, 0.02459333, 0.01839215],
#        [0.00034117, 0.00101683, 0.00081438],
#        [0.0003149 , 0.00174186, 0.00132342],
#        [0.00055593, 0.00099771, 0.00105945],
#        [0.00031423, 0.00253598, 0.00220196],
#        [0.00061615, 0.00283979, 0.00165793],
#        [0.01454525, 0.02411954, 0.01851439],
#        [0.00029262, 0.00122821, 0.00099089],
#        [0.00635018, 0.01237512, 0.00968009],
#        [0.00095538, 0.0046422 , 0.00227058],
#        [0.00038753, 0.00229036, 0.00179857],
#        [0.0114447 , 0.01967709, 0.01628755],
#        [0.00035003, 0.00098193, 0.00098513],
#        [0.0099487 , 0.01578343, 0.01281526],
#        [0.00039178, 0.00244183, 0.0016167 ],
#        [0.00034874, 0.00234453, 0.00171007],
#        [0.00028548, 0.00118118, 0.00094287],
#        [0.01719701, 0.02672932, 0.02384357],
#        [0.00695791, 0.01422049, 0.01088185],
#        [0.00402998, 0.01044604, 0.00786271],
#        [0.00040606, 0.0011712 , 0.00094565],
#        [0.02862472, 0.04195988, 0.0377639 ],
#        [0.033692  , 0.04959969, 0.04272478],
#        [0.00029281, 0.00108554, 0.00097168],
#        [0.00033739, 0.00182674, 0.0014878 ],
#        [0.00049197, 0.00281814, 0.00191284],
#        [0.00038112, 0.00231742, 0.00165639],
#        [0.0003549 , 0.00227587, 0.00144481],
#        [0.02657407, 0.0398809 , 0.03522059],
#        [0.02792019, 0.03853167, 0.03392319],
#        [0.01622114, 0.02718963, 0.02249366],
#        [0.00029108, 0.00116969, 0.0009957 ],
#        [0.00049188, 0.00278149, 0.00181496],
#        [0.01071468, 0.01924284, 0.01649703],
#        [0.00053619, 0.00096148, 0.00105125],
#        [0.00031795, 0.00115898, 0.00095464],
#        [0.00054106, 0.00104299, 0.00106575],
#        [0.01544631, 0.02378236, 0.02086768],
#        [0.00055611, 0.00104563, 0.00100097],
#        [0.03443145, 0.04422202, 0.03919337],
#        [0.00024317, 0.00125688, 0.00091975],
#        [0.01750332, 0.02858656, 0.02493531]], dtype=float32)

# %%
X_test2 = shp_clf.transform(X_test)
# Out:
# 36/36 [==============================] - 0s 83us/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train2, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8055555555555556
# F1-score [0.74074074 0.84444444]
#               precision    recall  f1-score   support
#
#            0       0.77      0.71      0.74        14
#            1       0.83      0.86      0.84        22
#
#     accuracy                           0.81        36
#    macro avg       0.80      0.79      0.79        36
# weighted avg       0.80      0.81      0.80        36

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.7777777777777778
# F1-score [0.71428571 0.81818182]
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71        14
#            1       0.82      0.82      0.82        22
#
#     accuracy                           0.78        36
#    macro avg       0.77      0.77      0.77        36
# weighted avg       0.78      0.78      0.78        36

# %% [markdown]
# # Feature-based Classifier

# %%
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
X_train3 = np.array([list(calculate_features(x).values()) for x in X_train])

# %%
X_train3.shape
# Out:
# (84, 13)

# %%
X_train3
# Out:
# array([[ 0.30229953,  0.20424212,  0.04171484, ...,  1.48010375,
#          0.77770243,  1.35148987],
#        [ 0.1953449 ,  0.20222478,  0.04089486, ...,  0.96597903,
#          2.11554316,  4.64082827],
#        [ 0.46100186,  0.20618162,  0.04251086, ...,  2.23590181,
#          0.33661711, -0.09446774],
#        ...,
#        [ 0.36100877,  0.23875035,  0.05700173, ...,  1.51207641,
#          0.9080769 ,  0.15477863],
#        [ 0.32534757,  0.34572681,  0.11952703, ...,  0.94105391,
#          0.50056553, -1.42701637],
#        [ 0.40615556,  0.22562106,  0.05090486, ...,  1.80016683,
#          0.83463791, -0.1653593 ]])

# %%
X_test3 = np.array([list(calculate_features(x).values()) for x in X_test])

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train3, y_train)

y_pred = clf.predict(X_test3)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9166666666666666
# F1-score [0.89655172 0.93023256]
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        14
#            1       0.95      0.91      0.93        22
#
#     accuracy                           0.92        36
#    macro avg       0.91      0.92      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %% [markdown]
# # Time Series Classifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9166666666666666
# F1-score [0.88888889 0.93333333]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.91      0.95      0.93        22
#
#     accuracy                           0.92        36
#    macro avg       0.92      0.91      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %%
from pyts.classification import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(metric='dtw_sakoechiba')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# # CNN Classifier

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling1D
from keras.layers import Conv1D, Activation, Conv1D, BatchNormalization

# %%
def build_simple_cnn(n_timesteps, n_outputs):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train_cnn, y_train, test_size=0.2, stratify=y_train)

n_timesteps, n_outputs, n_features = X_train_cnn.shape[1], len(np.unique(y_train_cnn)), 1 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
# Out:
# TIMESTEPS:  120
# N. LABELS:  2

# %%
cnn = build_simple_cnn(n_timesteps, n_outputs)

# %%
cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 113, 16)           144
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 113, 16)           64
# _________________________________________________________________
# activation_4 (Activation)    (None, 113, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 113, 16)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 109, 32)           2592
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 109, 32)           128
# _________________________________________________________________
# activation_5 (Activation)    (None, 109, 32)           0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 109, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 107, 64)           6208
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 107, 64)           256
# _________________________________________________________________
# activation_6 (Activation)    (None, 107, 64)           0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 107, 64)           0
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 9,522
# Trainable params: 9,298
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train_cnn.shape[0]/10, batch_size))

# %%
history_cnn = cnn.fit(X_train_cnn, y_train_cnn, epochs=5, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/5
# 18/67 [=======>......................] - ETA: 0s - loss: 0.8291 - accuracy: 0.3889
# C:\Users\carlo\Anaconda3\lib\site-packages\theano\tensor\subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 1s 12ms/step - loss: 0.7294 - accuracy: 0.4627 - val_loss: 0.6868 - val_accuracy: 0.5882
# Epoch 2/5
# 67/67 [==============================] - 1s 16ms/step - loss: 0.5985 - accuracy: 0.7612 - val_loss: 0.6843 - val_accuracy: 0.5882
# Epoch 3/5
# 67/67 [==============================] - 1s 16ms/step - loss: 0.5521 - accuracy: 0.7164 - val_loss: 0.6898 - val_accuracy: 0.5882
# Epoch 4/5
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4520 - accuracy: 0.8358 - val_loss: 0.6917 - val_accuracy: 0.5882
# Epoch 5/5
# 67/67 [==============================] - 1s 19ms/step - loss: 0.4033 - accuracy: 0.8657 - val_loss: 0.6924 - val_accuracy: 0.5882

# %%
y_pred = np.argmax(cnn.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cnn.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 0s 5ms/step
# [0.691463311513265, 0.6111111044883728]

# %% [markdown]
# # LSTM Classifier

# %%
from keras.layers import LSTM

# %%
def build_lstm(n_timesteps, n_outputs):
    model = Sequential()
    model.add(LSTM(64, input_shape=(n_timesteps, 1)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm = build_lstm(n_timesteps, n_outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a5fdd30c513f> in <module>
# ----> 1 lstm = build_lstm(n_timesteps, n_outputs)
#
# NameError: name 'n_timesteps' is not defined

# %%
lstm.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 256)               264192
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 280,770
# Trainable params: 280,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
                       validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/10
# 67/67 [==============================] - 1s 10ms/step - loss: 0.2868 - accuracy: 0.9254 - val_loss: 0.6930 - val_accuracy: 0.5882
# Epoch 2/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2976 - accuracy: 0.9104 - val_loss: 0.6935 - val_accuracy: 0.4706
# Epoch 3/10
# 67/67 [==============================] - 1s 10ms/step - loss: 0.2712 - accuracy: 0.9254 - val_loss: 0.6939 - val_accuracy: 0.4706
# Epoch 4/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3487 - accuracy: 0.8955 - val_loss: 0.6951 - val_accuracy: 0.2941
# Epoch 5/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2521 - accuracy: 0.9254 - val_loss: 0.6957 - val_accuracy: 0.3529
# Epoch 6/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2141 - accuracy: 0.9403 - val_loss: 0.6960 - val_accuracy: 0.3529
# Epoch 7/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2013 - accuracy: 0.9851 - val_loss: 0.6967 - val_accuracy: 0.2941
# Epoch 8/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.1872 - accuracy: 0.9552 - val_loss: 0.6950 - val_accuracy: 0.3529
# Epoch 9/10
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1542 - accuracy: 1.0000 - val_loss: 0.6982 - val_accuracy: 0.3529
# Epoch 10/10
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2079 - accuracy: 0.9552 - val_loss: 0.7009 - val_accuracy: 0.3529

# %%
y_pred = np.argmax(lstm.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36

# %%
lstm.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 1s 21ms/step
# [0.6966400676303439, 0.6111111044883728]

# %% [markdown]
# # Multivariate Time Series Classifiers

# %%
from pyts.datasets import load_basic_motions

from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_split:
    ts = temp[['Temperature','Humidity','CO2','Light','HumidityRatio']].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_split[1])
for ts in ts_list:
    ts_array.append(np.array(ts))
    
X = np.array(ts_array)

X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-01f9fbf9c10d> in <module>
#       2
#       3 ts_list = []
# ----> 4 for temp in day_split:
#       5     ts = temp[['Temperature','Humidity','CO2','Light','HumidityRatio']].copy()
#       6     ts_list.append(ts)
#
# NameError: name 'day_split' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %%
scaler = TimeSeriesScalerMinMax()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape, X_test.shape)

unique_elements, counts_elements = np.unique(y_train, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements, counts_elements = np.unique(y_test, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

# %%
n_timesteps, n_outputs, n_features = X_train.shape[1], len(np.unique(y_train)), X_train.shape[2] 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
print("N. FEATURES: ", n_features)

# %%
X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import TimeDistributed
from keras.layers.recurrent import LSTM
from keras.layers import Dense, Conv1D, Conv2D, MaxPool2D, Flatten, Dropout, LeakyReLU, GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
def build_lstm2(n_timesteps, n_outputs, n_features):
    model = Sequential()
    model.add(LSTM(4, input_shape=(n_timesteps, n_features), return_sequences=True, 
                        kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.3))
    
    #1
    for _ in range(2):
        model.add(LSTM(4, kernel_initializer='TruncatedNormal', return_sequences=True))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.04))   

    #2
    model.add(LSTM(32, kernel_initializer='TruncatedNormal', return_sequences=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
    
    #3
    for _ in range(2):
        model.add(Dense(256, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))
    #4
    for _ in range(1):
        model.add(Dense(64, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.7))

    #5
    model.add(Dense(32, kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.4))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# %%
lstm2.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_lstm2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_lstm2 = lstm2.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                          validation_data=(X_val_cnn, y_val_cnn)).history

# %%
y_pred = np.argmax(lstm2.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
X_train_cnn.shape

# %%
X_train_cnn2 = X_train_cnn.reshape(X_train_cnn.shape[0], X_train_cnn.shape[1], X_train_cnn.shape[2], 1)
X_val_cnn2 = X_val_cnn.reshape(X_val_cnn.shape[0], X_val_cnn.shape[1], X_val_cnn.shape[2], 1)
X_test_cnn2 = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

X_train_cnn2.shape

# %%
def build_cnn2(n_timesteps, n_features, n_outputs):
    input_shape = (n_timesteps, n_features, 1)

    model = Sequential()
    
    ks1_first = 3
    ks1_second = 3
    
    ks2_first = 4
    ks2_second = 4
    
    model.add(Conv2D(filters=(3), 
                     kernel_size=(ks1_first, ks1_second),
                     input_shape=input_shape, 
                     padding='same',
                     kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.02))
    
    for _ in range(2):
        model.add(Conv2D(filters=(4), 
                     kernel_size= (ks2_first, ks2_second), 
                         padding='same',
                     kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))  
    
    model.add(Flatten())
    
    for _ in range(4):
        model.add(Dense(64 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.4))
    
    for _ in range(3):
        model.add(Dense(128 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.3))
  
    model.add(Dense(1024 , kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn2 = build_cnn2(n_timesteps, n_features, n_outputs)

# %%
cnn2.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn2 = cnn2.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn2, y_val_cnn)).history

# %%
y_pred = np.argmax(cnn2.predict(X_test_cnn2), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
def build_cnn3(n_timesteps, n_outputs, n_features):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn3 = build_cnn3(n_timesteps, n_outputs, n_features)

# %%
cnn3.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn3 = cnn3.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history

# %%
y_pred = np.argmax(cnn3.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %% [markdown]
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.multivariate.classification.MultivariateClassifier.html#pyts.multivariate.classification.MultivariateClassifier
