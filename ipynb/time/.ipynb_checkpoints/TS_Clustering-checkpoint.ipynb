# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from collections import defaultdict
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
#plt.rcParams['figure.dpi']= 1000  #resolution

# %%
def draw_list(ts_list, attribute, ts_number=1000, formatter = None):
    if ts_number >= len(ts_list): ts_number = len(ts_list)-1
    fig = plt.figure()
    ax = fig.subplots()
    for ts in ts_list[:ts_number]:
        ax.plot(ts[attribute])
    ax.set_ylabel(attribute)
    if formatter !=None:
        date_form = DateFormatter(formatter)
        ax.xaxis.set_major_formatter(date_form)
    plt.show()

# %% [markdown]
# # Shape Based

# %%
time_col = 'date'
ts_size = 100
attribute = 'Temperature'
attributes = [time_col, attribute]

ts_list = []
df=pd.read_csv(r'../../data/datatraining.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon=df[df['Weekday']==0][attributes].copy()
tue=df[df['Weekday']==1][attributes].copy()
wed=df[df['Weekday']==2][attributes].copy() #N.B. -> mancano delle ore tra mezzogioro e le tre, incompleto 
thu=df[df['Weekday']==3][attributes].copy()
fri=df[df['Weekday']==4][attributes].copy()
sat=df[df['Weekday']==5][attributes].copy()
sun=df[df['Weekday']==6][attributes].copy()
weekdays =[mon,thu,fri,sat,sun]

for day in weekdays:
    day.sort_values(time_col, inplace=True)
    day[time_col]=day[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
    day[time_col]=pd.to_datetime(day[time_col], format='%H:%M:%S')  #now a date is setted automaticaly for all records
    day.set_index(time_col, inplace=True)
    #print(day) #usa per vedere ser i dati sno consistenti 
    while (len(day)>= ts_size):
        ts=day.sample(ts_size)
        ts.sort_values(time_col, inplace=True) #necessary to order
        ts_list.append(ts)
        day.drop(ts.index, axis=0, inplace=True)

        
        
df=pd.read_csv(r'../../data/datatest2.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon=df[df['Weekday']==0][attributes].copy()
tue=df[df['Weekday']==1][attributes].copy() 
wed=df[df['Weekday']==2][attributes].copy() #N.B. -> mancano delle ore tra mezzogioro e le tre, incompleto 
thu=df[df['Weekday']==3][attributes].copy()
fri=df[df['Weekday']==4][attributes].copy()
sat=df[df['Weekday']==5][attributes].copy()
sun=df[df['Weekday']==6][attributes].copy()
weekdays =[mon, tue, thu , fri, sat, sun] #wed is not here 

for day in weekdays:
    day.sort_values(time_col, inplace=True)
    day[time_col]=day[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
    day[time_col]=pd.to_datetime(day[time_col], format='%H:%M:%S')  #now a date is setted automaticaly for all records
    day.set_index(time_col, inplace=True)
    while (len(day)>= ts_size):
        ts=day.sample(ts_size)
        ts.sort_values(time_col, inplace=True) #necessary to order
        ts_list.append(ts)
        day.drop(ts.index, axis=0, inplace=True)

# %%
def draw_list(ts_list, attribute, ts_number=1000, formatter = None):
    if ts_number >= len(ts_list): ts_number = len(ts_list)-1
    fig = plt.figure()
    ax = fig.subplots()
    for ts in ts_list[:ts_number]:
        ax.plot(ts[attribute])
    ax.set_ylabel(attribute)
    if formatter !=None:
        date_form = DateFormatter(formatter)
        ax.xaxis.set_major_formatter(date_form)
    plt.show()
    
    
draw_list(ts_list, attribute,formatter='%H')

# %%
new_ts=[]
for ts in ts_list:
    new_ts.append((ts-ts.mean())/ts.std())
draw_list(new_ts, attribute, formatter = '%H')

# %%
ts_list = new_ts
#for ts in ts_list:
 #   ts.reset_index(drop=True, inplace=True)
    
ts_array = []

for ts in ts_list:
    ts_array.append(np.array(ts).reshape(ts_size,))
    
ts_array = np.array(ts_array)
ts_array.shape
# Out:
# (154, 100)

# %%
from tslearn.clustering import TimeSeriesKMeans
from tslearn.generators import random_walks

km = TimeSeriesKMeans(n_clusters=2, metric="dtw", max_iter=5, random_state=0)
km.fit(ts_array)

plt.plot(km.cluster_centers_.reshape(ts_array.shape[1], 2))
plt.show()

# %%
supp_list=[]
for ts in ts_list:
    ts_copy=ts.copy()
    supp_list.append(ts_copy)
    
ts_part_list = []
length = len(supp_list[0])//3

for ts in supp_list:
    i=0
    while(i<3):
        ts_part = ts[:length]
        ts.drop(ts_part.index, axis=0, inplace=True)
        ts_part_list.append(ts_part)
        i+=1

for ts in ts_part_list:
    ts.reset_index(drop=True, inplace=True)
random.shuffle(ts_part_list)
draw_list(ts_part_list , attribute, 7)

# %%
ts_array = []
ts_size = 33
for ts in ts_part_list:
    ts_array.append(np.array(ts).reshape(ts_size,))
    
ts_array = np.array(ts_array)
ts_array.shape
# Out:
# (462, 33)

# %%
from tslearn.clustering import TimeSeriesKMeans
from tslearn.generators import random_walks

km = TimeSeriesKMeans(n_clusters=3, metric="euclidean", max_iter=5, random_state=0)
km.fit(ts_array)

plt.plot(km.cluster_centers_.reshape(ts_array.shape[1], 3))
plt.show()

# %% [markdown]
# # Feature Based

# %%
time_col = 'date'
ts_size = 100

attributes = [time_col,'Temperature','Humidity']

ts_list = []
df=pd.read_csv(r'../../data/datatraining.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon=df[df['Weekday']==0][attributes].copy()
tue=df[df['Weekday']==1][attributes].copy()
wed=df[df['Weekday']==2][attributes].copy() #N.B. -> mancano delle ore tra mezzogioro e le tre, incompleto 
thu=df[df['Weekday']==3][attributes].copy()
fri=df[df['Weekday']==4][attributes].copy()
sat=df[df['Weekday']==5][attributes].copy()
sun=df[df['Weekday']==6][attributes].copy()
weekdays =[mon,thu,fri,sat,sun]

for day in weekdays:
    day.sort_values(time_col, inplace=True)
    day[time_col]=day[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
    day[time_col]=pd.to_datetime(day[time_col], format='%H:%M:%S')  #now a standard date is setted automaticaly for all records
    day.set_index(time_col, inplace=True)
    #print(day) #usa per vedere ser i dati sno consistenti 
    while (len(day)>= ts_size):
        ts=day.sample(ts_size)
        ts.sort_values(time_col, inplace=True) #necessary to order
        ts_list.append(ts)
        day.drop(ts.index, axis=0, inplace=True)

        
        
df=pd.read_csv(r'../../data/datatest2.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon=df[df['Weekday']==0][attributes].copy()
tue=df[df['Weekday']==1][attributes].copy() 
wed=df[df['Weekday']==2][attributes].copy() #N.B. -> mancano delle ore tra mezzogioro e le tre, incompleto 
thu=df[df['Weekday']==3][attributes].copy()
fri=df[df['Weekday']==4][attributes].copy()
sat=df[df['Weekday']==5][attributes].copy()
sun=df[df['Weekday']==6][attributes].copy()
weekdays =[mon, tue, thu , fri, sat, sun] #wed is not here 

for day in weekdays:
    day.sort_values(time_col, inplace=True)
    day[time_col]=day[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
    day[time_col]=pd.to_datetime(day[time_col], format='%H:%M:%S')  #now a date is setted automaticaly for all records
    day.set_index(time_col, inplace=True)
    while (len(day)>= ts_size):
        ts=day.sample(ts_size)
        ts.sort_values(time_col, inplace=True) #necessary to order
        ts_list.append(ts)
        day.drop(ts.index, axis=0, inplace=True)

# %%
import numpy as np
import scipy.stats as stats

def calculate_features(ts):
    features = {
        'maxT': [np.max(ts['Temperature'])],
        'minT':[np.min(ts['Temperature'])],
        'avgT': [np.mean(ts['Temperature'])],
        'stdT': [np.std(ts['Temperature'])],
        'maxH': [np.max(ts['Humidity'])],
        'minH':[np.min(ts['Humidity'])],
        'avgH': [np.mean(ts['Humidity'])],
        'stdH': [np.std(ts['Humidity'])],
    
    }
    return features

# %%
F = pd.DataFrame()
for ts in ts_list:
    F = F.append( pd.DataFrame.from_dict(calculate_features(ts)), ignore_index = True)
F
# Out:
#        maxT       minT       avgT      stdT       maxH       minH       avgH  \
# 0    22.100  19.290000  20.704500  1.036174  39.022500  25.890000  32.492108
# 1    22.100  19.290000  20.484900  0.960598  39.022500  26.200000  31.712175
# 2    22.290  19.290000  20.479158  0.983478  39.067500  25.890000  31.546933
# 3    22.200  19.290000  20.670867  0.995167  39.090000  25.890000  32.457592
# 4    22.200  19.290000  20.569325  1.000255  39.000000  26.033333  31.992533
# ..      ...        ...        ...       ...        ...        ...        ...
# 149  23.200  19.890000  20.581708  0.839264  35.590000  28.472500  31.867975
# 150  23.245  19.890000  20.842008  0.989941  35.500000  28.445000  31.669033
# 151  23.100  19.890000  20.977525  0.981419  35.663333  28.500000  31.270175
# 152  22.700  19.856667  20.635308  0.840354  35.745000  28.700000  31.967175
# 153  22.790  19.890000  20.782083  0.835836  35.590000  28.700000  31.530368
#
#          stdH
# 0    4.569087
# 1    4.183052
# 2    4.338133
# 3    4.257930
# 4    4.286373
# ..        ...
# 149  1.792104
# 150  1.896874
# 151  2.019545
# 152  1.947677
# 153  1.744594
#
# [154 rows x 8 columns]

# %%
ts_array_T = []
ts_array_H = []
ts_size = 100
for ts in ts_list:
    ts_array_T.append(np.array(ts['Temperature']).reshape(ts_size,))
    ts_array_H.append(np.array(ts['Humidity']).reshape(ts_size,))
ts_array_T = np.array(ts_array_T)
ts_array_H = np.array(ts_array_H)
ts_array_T.shape
# Out:
# (154, 100)

# %%
ts_array
# Out:
# array([[ 1.92460339,  1.76284709,  1.84372524, ..., -1.31052256,
#         -1.4183601 , -1.65021079],
#        [-0.76114653, -0.76114653, -0.76114653, ...,  1.34878724,
#          1.65480817,  1.61454226],
#        [-0.75019476, -0.63532654, -0.63532654, ...,  1.08769673,
#          1.08769673,  0.97282852],
#        ...,
#        [-1.02985643, -1.02985643, -1.02985643, ..., -1.23170112,
#         -1.1355846 , -1.10034188],
#        [-0.39429561, -0.44601679, -0.49773797, ...,  1.38303212,
#          1.20435896,  0.71065682],
#        [ 1.37073688,  1.70100966,  1.70100966, ..., -1.05912713,
#         -1.12989987, -1.12989987]])

# %%
ts_array[np.where(kmeans.labels_ == i)]
# Out:
# array([], shape=(0, 33), dtype=float64)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(F)

print(kmeans.inertia_)

for i in range(3):
    plt.plot(np.mean(ts_array_H[np.where(kmeans.labels_ == i)], axis=0))
plt.show()
for i in range(3):
    plt.plot(np.mean(ts_array_T[np.where(kmeans.labels_ == i)], axis=0))
    plt.xticks([(100/24 * i) for i in range(25)],list(range(25)))
plt.show()
# Out:
# 2352.298644886498

# %%
supp_list=[]
for ts in ts_list:
    ts_copy=ts.copy()
    supp_list.append(ts_copy)
    
ts_part_list = []
length = len(supp_list[0])//3

for ts in supp_list:
    i=0
    while(i<3):
        ts_part = ts[:length]
        ts.drop(ts_part.index, axis=0, inplace=True)
        ts_part_list.append(ts_part)
        i+=1

for ts in ts_part_list:
    ts.reset_index(drop=True, inplace=True)
random.shuffle(ts_part_list)
draw_list(ts_part_list, attribute,40)

# %%
for ts in ts_part_list:
    print(len(ts['Temperature']))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %%
ts_array_T = []
ts_array_H = []
ts_size = 33
for ts in ts_part_list:
    ts_array_T.append(np.array(ts['Temperature']).reshape(ts_size,))
    ts_array_H.append(np.array(ts['Humidity']).reshape(ts_size,))
ts_array_T = np.array(ts_array_T)
ts_array_H = np.array(ts_array_H)
ts_array_T.shape
# Out:
# (462, 33)

# %%
F = pd.DataFrame()
for ts in ts_list:
    F = F.append( pd.DataFrame.from_dict(calculate_features(ts)), ignore_index = True)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)
kmeans.fit(F)

print(kmeans.inertia_)

for i in range(3):
    plt.plot(np.mean(ts_array_H[np.where(kmeans.labels_ == i)], axis=0))
plt.show()
for i in range(3):
    plt.plot(np.mean(ts_array_T[np.where(kmeans.labels_ == i)], axis=0))
    plt.xticks([(33/24 * i) for i in range(25)],list(range(25)))
plt.show()
# Out:
# 2352.298644886498

# %% [markdown]
# # Data Preparation

# %%
ts_array[4]
# Out:
# array([[29.29      ],
#        [29.2       ],
#        [29.2       ],
#        [29.05      ],
#        [28.79      ],
#        [28.745     ],
#        [28.29      ],
#        [28.05      ],
#        [28.        ],
#        [27.7       ],
#        [27.6       ],
#        [27.55      ],
#        [27.5       ],
#        [27.5       ],
#        [27.39      ],
#        [27.1       ],
#        [27.        ],
#        [26.89      ],
#        [26.89      ],
#        [26.7       ],
#        [26.445     ],
#        [26.5       ],
#        [26.5       ],
#        [26.39      ],
#        [26.2675    ],
#        [26.1       ],
#        [25.79      ],
#        [25.745     ],
#        [25.66666667],
#        [25.65      ],
#        [25.63333333],
#        [25.6       ],
#        [25.5       ],
#        [25.29      ],
#        [25.29      ],
#        [25.1       ],
#        [25.        ],
#        [25.        ],
#        [24.89      ],
#        [24.79      ],
#        [24.79      ],
#        [24.7       ],
#        [24.6       ],
#        [24.29      ],
#        [24.29      ],
#        [24.34      ],
#        [25.7       ],
#        [25.865     ],
#        [27.1       ],
#        [27.3225    ]])

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m')
df = pd.read_csv('AirPassengers.csv', parse_dates=True, index_col='Month', date_parser=dateparse)
df.head()

# %%
ts = df['#Passengers']
plt.plot(ts)
plt.show()

# %% [markdown]
# ### Generate Random Time Series

# %%
ts1 = pd.Series([np.sin(float(x)/20.)+np.random.rand()/2. for x in range(200)])
ts2 = pd.Series([1.5*np.sin(float(x)/20.)+np.random.rand()/2.+0.8 for x in range(200)])
plt.plot(ts1)
plt.plot(ts2)
plt.show()

# %% [markdown]
# # Transformations

# %% [markdown]
# ### Transformation I: Offset Translation

# %%
plt.plot(ts1 - ts1.mean())
plt.plot(ts2 - ts2.mean())
plt.show()

# %% [markdown]
# ### Transformation II: Amplitude Scaling

# %%
plt.plot((ts1 - ts1.mean())/ts1.std())
plt.plot((ts2 - ts2.mean())/ts2.std())
plt.show()

# %%
from tslearn.preprocessing import TimeSeriesScalerMeanVariance

# %% [markdown]
# https://tslearn.readthedocs.io/en/latest/index.html

# %%
scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)  # Rescale time series
ts1_scaled = scaler.fit_transform(ts1).flatten()
ts2_scaled = scaler.fit_transform(ts2).flatten()

plt.plot(ts1_scaled)
plt.plot(ts2_scaled)
plt.show()

# %% [markdown]
# ### Transformation IV: Noise (smoothing)

# %%
w = 10
plt.plot(((ts1 - ts1.mean())/ts1.std()).rolling(window=w).mean())
plt.plot(((ts2 - ts2.mean())/ts2.std()).rolling(window=w).mean())
plt.show()

# %% [markdown]
# ### Transformation III: Trend removal

# %%
ts = df['#Passengers']
plt.plot(ts)
plt.show()

# %%
plt.plot(ts)
plt.plot(ts.rolling(window=12).mean())
plt.show()

# %%
ts_shift = ts - ts.rolling(window=12).mean()
plt.plot(ts_shift)
plt.show()

# %%
#ts_shift2 = ts - ts.ewm(halflife=12).mean()
#plt.plot(ts_shift, 'r-')
#plt.plot(ts_shift2, 'b-')
#plt.show()

# %% [markdown]
# # Euclidean Distance

# %%
from scipy.spatial.distance import euclidean

# %%
dist = euclidean(ts1, ts2)
dist

# %%
dist = euclidean(ts1[:10], ts2[:10])
dist

# %% [markdown]
# # Manhattan Distance

# %%
from scipy.spatial.distance import cityblock

# %%
dist = cityblock(ts1, ts2)
dist

# %%
dist = cityblock(ts1[:10], ts2[:10])
dist

# %% [markdown]
# # Dynamic Time Warping

# %%
from tslearn.metrics import dtw, dtw_path, cdist_dtw, subsequence_cost_matrix

# %%
dist = dtw(ts1, ts2)
dist

# %%
dist = dtw(ts1[:10], ts2[:10])
dist

# %%
path, dist = dtw_path(ts1[:10], ts2[:10])

# %%
path

# %%
from scipy.spatial.distance import cdist

# %%
mat = cdist(ts1.values[:10].reshape(-1,1), ts2.values[:10].reshape(-1,1))

plt.imshow(mat)
plt.axis("off")
plt.autoscale(False)
for i in range(mat.shape[0]):
    for j in range(mat.shape[1]):
        text = plt.text(j, i, '%.1f' % mat[i, j], ha="center", va="center", color="w")
        
plt.show()

# %%
acc = subsequence_cost_matrix(ts1.values[:10].reshape(-1,1), ts2.values[:10].reshape(-1,1))

plt.imshow(acc)
plt.axis("off")
plt.autoscale(False)
for i in range(acc.shape[0]):
    for j in range(acc.shape[1]):
        text = plt.text(j, i, '%.1f' % np.sqrt(acc[i, j]), ha="center", va="center", color="w")
        
plt.show()

# %%
plt.imshow(mat)
plt.axis("off")
plt.autoscale(False)
plt.plot([j for (i, j) in path], [i for (i, j) in path], "w-", linewidth=3.)
plt.show()

# %%
path, dist = dtw_path(ts1[:10], ts2[:10], global_constraint="sakoe_chiba", sakoe_chiba_radius=2)
dist

# %%
plt.imshow(mat)
plt.axis("off")
plt.autoscale(False)
plt.plot([j for (i, j) in path], [i for (i, j) in path], "w-", linewidth=3.)
plt.show()

# %%
path, dist = dtw_path(ts1[:10], ts2[:10], global_constraint="itakura", itakura_max_slope=2.)
dist

# %%
plt.imshow(mat)
plt.axis("off")
plt.autoscale(False)
plt.plot([j for (i, j) in path], [i for (i, j) in path], "w-", linewidth=3.)
plt.show()

# %%
cdist_dtw([ts1, ts2, ts])

# %% [markdown]
# ### DTW2

# %%
from pyts.metrics import dtw as dtw2

# %%
dtw2(ts1[:10].ravel(), ts2[:10].ravel())

# %%
dtw2(ts1[:10].ravel(), ts2[:10].ravel(), dist='absolute')

# %%
dtw2(ts1[:10].ravel(), ts2[:10].ravel(), dist='square', method='fast')

# %%
dtw2(ts1[:10].ravel(), ts2[:10].ravel(), dist='absolute', method='fast')

# %% [markdown]
# # Features Extraction

# %%
import numpy as np
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
features = calculate_features(ts)

# %%
features

# %%
from tsfresh.feature_extraction import extract_features

# %% [markdown]
# https://tsfresh.readthedocs.io/en/latest/index.html

# %%
df['id'] = df.index

# %%
features = extract_features(timeseries_container=df, column_id='id')

# %%
features.to_dict()

# %% [markdown]
# # Compression-based Distances

# %%
import zlib
import string

# %%
s = "Hello world!"
print(s)
print(s.encode('utf-8'))
zlib.compress(s.encode('utf-8'))

# %%
def CDM(x, y):
    return len(zlib.compress(x + y)) / (len(zlib.compress(x)) + len(zlib.compress(y)))

# %%
ts1_str = (' '.join([str(v) for v in ts1[:10]])).encode('utf-8')
ts1_str

# %%
ts2_str = (' '.join([str(v) for v in ts2[:10]])).encode('utf-8')
ts2_str

# %%
print("len(ts1_str + ts2_str): ", len(ts1_str + ts2_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts1_str+ts2_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts1_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts2_str)))
print("CDM = ", CDM(ts1_str, ts2_str))

# %%
ts1_str = (' '.join([str(v) for v in ts1])).encode('utf-8')
ts2_str = (' '.join([str(v) for v in ts2])).encode('utf-8')

print("len(ts1_str + ts2_str): ", len(ts1_str + ts2_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts1_str+ts2_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts1_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts2_str)))
print("CDM = ", CDM(ts1_str, ts2_str))

# %% [markdown]
# # Time Series Approximation

# %%
from tslearn.piecewise import PiecewiseAggregateApproximation
from tslearn.piecewise import SymbolicAggregateApproximation
from tslearn.piecewise import OneD_SymbolicAggregateApproximation

# %%
scaler = TimeSeriesScalerMeanVariance(mu=0., std=1.)  # Rescale time series
ts = scaler.fit_transform(ts)
ts1 = scaler.fit_transform(ts1)
ts2 = scaler.fit_transform(ts2)

# %%
# PAA transform (and inverse transform) of the data
n_paa_segments = 10
paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)
ts_paa = paa.fit_transform(ts)
paa_dataset_inv = paa.inverse_transform(ts_paa)

# SAX transform
n_sax_symbols = 8
sax = SymbolicAggregateApproximation(n_segments=n_paa_segments, alphabet_size_avg=n_sax_symbols)
ts_sax = sax.fit_transform(ts)
sax_dataset_inv = sax.inverse_transform(ts_sax)

# 1d-SAX transform
n_sax_symbols_avg = 8
n_sax_symbols_slope = 4
one_d_sax = OneD_SymbolicAggregateApproximation(
    n_segments=n_paa_segments,
    alphabet_size_avg=n_sax_symbols_avg,
    alphabet_size_slope=n_sax_symbols_slope)

ts_sax1d = one_d_sax.fit_transform(ts)
one_d_sax_dataset_inv = one_d_sax.inverse_transform(ts_sax1d)

plt.figure()
plt.subplot(2, 2, 1)  # First, raw time series
plt.plot(ts[0].ravel(), "b-")
plt.title("Raw time series")

plt.subplot(2, 2, 2)  # Second, PAA
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(paa_dataset_inv[0].ravel(), "b-")
plt.title("PAA")

plt.subplot(2, 2, 3)  # Then SAX
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(sax_dataset_inv[0].ravel(), "b-")
plt.title("SAX, %d symbols" % n_sax_symbols)

plt.subplot(2, 2, 4)  # Finally, 1d-SAX
plt.plot(ts[0].ravel(), "b-", alpha=0.4)
plt.plot(one_d_sax_dataset_inv[0].ravel(), "b-")
plt.title("1d-SAX, %d symbols"
          "(%dx%d)" % (n_sax_symbols_avg * n_sax_symbols_slope,
                       n_sax_symbols_avg,
                       n_sax_symbols_slope))

plt.tight_layout()
plt.show()

# %%
plt.plot(ts1[0].ravel())
plt.plot(ts2[0].ravel())
plt.show()

# %%
ts1_paa = paa.fit_transform(ts1)
ts2_paa = paa.fit_transform(ts2)

# %%
plt.plot(paa.inverse_transform(ts1_paa)[0].ravel())
plt.plot(paa.inverse_transform(ts2_paa)[0].ravel())
plt.show()

# %%
ts1_str = (' '.join([str(v) for v in ts1_paa[0].ravel()])).encode('utf-8')
ts2_str = (' '.join([str(v) for v in ts2_paa[0].ravel()])).encode('utf-8')

print("len(ts1_str + ts2_str): ", len(ts1_str + ts2_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts1_str+ts2_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts1_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts2_str)))
print("CDM = ", CDM(ts1_str, ts2_str))

# %%
ts1_sax = sax.fit_transform(ts1)
ts2_sax = sax.fit_transform(ts2)

# %%
plt.plot(sax.inverse_transform(ts1_sax)[0].ravel())
plt.plot(sax.inverse_transform(ts2_sax)[0].ravel())
plt.show()

# %%
ts1_str = (' '.join([str(v) for v in ts1_sax[0].ravel()])).encode('utf-8')
ts2_str = (' '.join([str(v) for v in ts2_sax[0].ravel()])).encode('utf-8')

print("len(ts1_str + ts2_str): ", len(ts1_str + ts2_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts1_str+ts2_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts1_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts2_str)))
print("CDM = ", CDM(ts1_str, ts2_str))

# %%
ts1_sax1d = one_d_sax.fit_transform(ts1)
ts2_sax1d = one_d_sax.fit_transform(ts2)

# %%
plt.plot(one_d_sax.inverse_transform(ts1_sax1d)[0].ravel())
plt.plot(one_d_sax.inverse_transform(ts2_sax1d)[0].ravel())
plt.show()

# %%
ts1_str = (' '.join([str(v) for v in ts1_sax1d[0].ravel()])).encode('utf-8')
ts2_str = (' '.join([str(v) for v in ts2_sax1d[0].ravel()])).encode('utf-8')

print("len(ts1_str + ts2_str): ", len(ts1_str + ts2_str))
print("len(compress(ts1_str+ts2_str)): ", len(zlib.compress(ts1_str+ts2_str)))
print("len(compress(ts1_str)): ", len(zlib.compress(ts1_str)))
print("len(compress(ts2_str)): ", len(zlib.compress(ts2_str)))
print("CDM = ", CDM(ts1_str, ts2_str))

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Shape-based Clustering

# %%
from tslearn.clustering import TimeSeriesKMeans
from tslearn.generators import random_walks

# %%
X = random_walks(n_ts=50, sz=32, d=1)

# %%
X.shape

# %%
plt.plot(X.reshape(X.shape[1], X.shape[0]))
plt.show()

# %%
km = TimeSeriesKMeans(n_clusters=3, metric="euclidean", max_iter=5, random_state=0)
km.fit(X)

# %%
plt.plot(km.cluster_centers_.reshape(X.shape[1], 3))
plt.show()

# %%
km.labels_

# %%
km.inertia_

# %%
km_dtw = TimeSeriesKMeans(n_clusters=3, metric="dtw", max_iter=5, random_state=0)
km_dtw.fit(X)

# %%
plt.plot(km_dtw.cluster_centers_.reshape(X.shape[1], 3))
plt.show()

# %%
km_dtw.labels_

# %%
km_dtw.inertia_

# %% [markdown]
# ## Features-based Clustering

# %%
from sklearn.cluster import KMeans

# %%
F = [list(calculate_features(x).values())[:2] for x in X]

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(F)

# %%
kmeans.inertia_

# %%
for i in range(3):
    plt.plot(np.mean(X[np.where(kmeans.labels_ == i)[0]], axis=0))
plt.show()

# %% [markdown]
# # Compression-based Clustering

# %%
from sklearn.metrics import pairwise_distances

# %%
def cdm_dist(x, y):
    x_str = (' '.join([str(v) for v in x.ravel()])).encode('utf-8')
    y_str = (' '.join([str(v) for v in y.ravel()])).encode('utf-8')
    return len(zlib.compress(x_str + y_str)) / (len(zlib.compress(x_str)) + len(zlib.compress(y_str)))

# %%
M = pairwise_distances(X.reshape(X.shape[0], X.shape[1]), metric=cdm_dist)

# %%
M.shape

# %%
plt.plot(sorted(M.ravel()))
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbscan = DBSCAN(eps=0.965, min_samples=5, metric='precomputed')
dbscan.fit(M)

# %%
dbscan.labels_

# %% [markdown]
# # Approximated Clustering

# %%
n_paa_segments = 10
paa = PiecewiseAggregateApproximation(n_segments=n_paa_segments)
X_paa = paa.fit_transform(X)

# %%
plt.plot(X_paa.reshape(X_paa.shape[1], X_paa.shape[0]))
plt.show()

# %%
km = TimeSeriesKMeans(n_clusters=3, metric="euclidean", max_iter=5, random_state=0)
km.fit(X_paa)

# %%
plt.plot(km.cluster_centers_.reshape(X_paa.shape[1], 3))
plt.show()

# %%
km.labels_

# %%
for i in range(3):
    plt.plot(np.mean(X[np.where(km.labels_ == i)[0]], axis=0))
plt.show()
