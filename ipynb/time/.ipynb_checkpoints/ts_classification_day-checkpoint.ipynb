# %% [markdown]
# **Author:** [Riccardo Guidotti](http://kdd.isti.cnr.it/people/riccardo-guidotti)
# **Python version:**  3.x

# %%
# %matplotlib inline
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
from collections import defaultdict
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
#plt.rcParams['figure.dpi']= 300  #resolution

from collections import defaultdict

# %%
def draw_list(ts_list, attribute, ts_number=1000, time = None , formatter = None):
    if ts_number >= len(ts_list): ts_number = len(ts_list)-1
    fig = plt.figure()
    ax = fig.subplots()
    for ts in ts_list[:ts_number]:
        if time == None: index = list(ts.index.values)
        else: index= ts[time]
        ax.plot(index, ts[attribute])
    ax.set_ylabel(attribute)
    if formatter !=None:
        date_form = DateFormatter(formatter)
        ax.xaxis.set_major_formatter(date_form)
    plt.show()

# %% [markdown]
# # Data Preparation

# %%
time_col = 'date'

attributes = ['date', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio', 'Occupancy','Weekday']


df=pd.read_csv(r'../../data/datatraining.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())

mon1=df[df['Weekday']==0][attributes].copy()
tue1=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed1=df[df['Weekday']==2][attributes].copy() #incompleted too
thu1=df[df['Weekday']==3][attributes].copy()
fri1=df[df['Weekday']==4][attributes].copy()
sat1=df[df['Weekday']==5][attributes].copy()
sun1=df[df['Weekday']==6][attributes].copy()
    
weekdays1 = [thu1,fri1,sat1,sun1,mon1] #I dont want incompleted days, so wednesday and tuesday are excluded



df=pd.read_csv(r'../../data/datatest2.txt')
df[time_col] =  pd.to_datetime(df[time_col], format = '%Y-%m-%d %H:%M:%S')
df['Weekday']=df[time_col].apply(lambda x:x.weekday())
                                 
mon2=df[df['Weekday']==0][attributes].copy()
tue2=df[df['Weekday']==1][attributes].copy()  #missing part of the day
wed2=df[df['Weekday']==2][attributes].copy() #incompleted too
thu2=df[df['Weekday']==3][attributes].copy()
fri2=df[df['Weekday']==4][attributes].copy()
sat2=df[df['Weekday']==5][attributes].copy()
sun2=df[df['Weekday']==6][attributes].copy()
    
weekdays2 = [thu2,fri2,sat2,sun2,mon2] #I dont want incompleted days, so wednesday and tuesday are excluded

# %% [markdown]
# ## week list

# %%
week_size = 144
week_list = []

week1 = pd.DataFrame()
for day in weekdays1:
    day.sort_values(time_col, inplace=True)#first of all: order
    week1 = week1.append(day, ignore_index=True )    ##a week

week1_list = []
tmp = week1.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week1_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
week2 = pd.DataFrame()
for day in weekdays2:    
    day.sort_values(time_col, inplace=True)#first of all: order
    week2 = week2.append(day, ignore_index=True)    ##a week
    
week2_list = []
tmp = week2.copy() 
while(len(tmp)>=week_size):
    ts = tmp.sample(week_size)
    ts.sort_values(time_col, inplace=True)
    week2_list.append(ts)
    week_list.append(ts)
    tmp.drop(ts.index, axis=0, inplace=True) #remove the sample just extract

    
random.shuffle(week_list)
draw_list(week_list, 'Temperature', 15, time = time_col ,formatter = '%d')

# %% [markdown]
# ## day_list

# %%
day_list = []
day_size = 120

day1_list=[]
for day in weekdays1:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day1_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extra


day2_list = []
for day in weekdays2:
    day_copy =day.copy()
    day_copy.reset_index(drop=True, inplace=True)
    while (len(day_copy)>= day_size):
        day_copy['time']=day_copy[time_col].apply(lambda x: str(x)[11:19]) #get string %H:%M:%S and lose info about the daydate
        day_copy['time']=pd.to_datetime(day_copy['time'], format='%H:%M:%S')  #now a date is setted automaticaly for all records
        ts=day_copy.sample(day_size)
        ts.sort_values('time', inplace=True) #necessary to order to be sure
        day_list.append(ts)
        day2_list.append(ts)
        day_copy.drop(ts.index, axis=0, inplace=True) #remove the sample just extract


draw_list(day_list, 'Temperature', time = 'time', formatter = '%H')

# %%
# Out:
# 2       3
# 9       3
# 11      3
# 31      3
# 56      3
#        ..
# 1342    3
# 1347    3
# 1409    3
# 1428    3
# 1436    3
# Name: Weekday, Length: 120, dtype: int64

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_list:
    ts = temp['CO2'].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_list[1])
for ts in ts_list:
    ts_array.append(np.array(ts).reshape(ts_size,))
    
X = np.array(ts_array)

weekend = lambda ts: 'Weekday' if int(ts['Weekday'][ts.index[0]])< 5 else 'Holiday' 
labels = np.array([weekend(ts) for ts in day_list ])

y = preprocessing.LabelEncoder().fit_transform(labels)
plt.figure()
for i, classe in enumerate(['Weekday','Holiday']):
    plt.subplot(2, 1, i + 1)
    for x in X[labels == classe]:
        plt.plot(x, color='C'+str(i), linewidth=0.9)
    plt.title('Class: {}'.format(classe), fontsize=16)

#plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()

# %% [markdown]
# # Data Normalization

# %%
from keras.optimizers import Adagrad
from tslearn.shapelets import ShapeletModel
from tslearn.shapelets import grabocka_params_to_shapelet_size_dict

from tslearn.preprocessing import TimeSeriesScalerMinMax

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score
# Out:
# Using Theano backend.
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.cluster.k_means_ module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.cluster. Anything that cannot be imported from sklearn.cluster is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
scaler = TimeSeriesScalerMinMax()
X = scaler.fit_transform(X).reshape(X.shape[0], X.shape[1])

# %% [markdown]
# # Data Partitioning

# %%
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %% [markdown]
# # Shaplet Classifier

# %%
n_ts, ts_sz = X_train.shape
n_classes = len(set(y))

# Set the number of shapelets per size as done in the original paper
shapelet_sizes = grabocka_params_to_shapelet_size_dict(n_ts=n_ts,
                                                       ts_sz=ts_sz,
                                                       n_classes=n_classes,
                                                       l=0.1,
                                                       r=1)

print('n_ts', n_ts)
print('ts_sz', ts_sz)
print('n_classes', n_classes)
print('shapelet_sizes', shapelet_sizes)
# Out:
# n_ts 84
# ts_sz 120
# n_classes 2
# shapelet_sizes {12: 3}

# %%
# Define the model using parameters provided by the authors (except that we use
# fewer iterations here)
shp_clf = ShapeletModel(n_shapelets_per_size=shapelet_sizes,
                        optimizer="sgd",
                        weight_regularizer=.01,
                        max_iter=200,
                        verbose=1)

# %%
shp_clf.fit(X_train, y_train)
# Out:
# Epoch 1/200
# 84/84 [==============================] - 0s 583us/step - loss: 0.7019 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6957
# Epoch 2/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.7018 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6956
# Epoch 3/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.7017 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6955
# Epoch 4/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.7016 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6954
# Epoch 5/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.7015 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6953
# Epoch 6/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.7014 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6953
# Epoch 7/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.7014 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6952
# Epoch 8/200
# 84/84 [==============================] - 0s 560us/step - loss: 0.7013 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6951
# Epoch 9/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.7012 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6950
# Epoch 10/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.7011 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6949
# Epoch 11/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.7010 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6948
# Epoch 12/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.7009 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6947
# Epoch 13/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.7008 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6946
# Epoch 14/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.7007 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6946
# Epoch 15/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.7006 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6945
# Epoch 16/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.7006 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6944
# Epoch 17/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.7005 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6943
# Epoch 18/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.7004 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6942
# Epoch 19/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.7003 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6941
# Epoch 20/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.7002 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6941
# Epoch 21/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.7001 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6940
# Epoch 22/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.7001 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6939
# Epoch 23/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.7000 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6938
# Epoch 24/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6999 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6937
# Epoch 25/200
# 84/84 [==============================] - 0s 357us/step - loss: 0.6998 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6937
# Epoch 26/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6997 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6936
# Epoch 27/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6996 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6935
# Epoch 28/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6996 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6934
# Epoch 29/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6995 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6933
# Epoch 30/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6994 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6933
# Epoch 31/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6993 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6932
# Epoch 32/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6992 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6931
# Epoch 33/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6992 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6930
# Epoch 34/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6991 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6930
# Epoch 35/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6990 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6929
# Epoch 36/200
# 84/84 [==============================] - 0s 262us/step - loss: 0.6989 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6928
# Epoch 37/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6988 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6927
# Epoch 38/200
# 84/84 [==============================] - 0s 250us/step - loss: 0.6988 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6927
# Epoch 39/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6987 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6926
# Epoch 40/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6986 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6925
# Epoch 41/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6985 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6924
# Epoch 42/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6985 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6924
# Epoch 43/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6984 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6923
# Epoch 44/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6983 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6922
# Epoch 45/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6982 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6921
# Epoch 46/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6981 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6921
# Epoch 47/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6981 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6920
# Epoch 48/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6980 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6919
# Epoch 49/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6979 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6919
# Epoch 50/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6979 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6918
# Epoch 51/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6978 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6917
# Epoch 52/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6977 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6916
# Epoch 53/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6976 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6916
# Epoch 54/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6976 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6915
# Epoch 55/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6975 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6914
# Epoch 56/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6974 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6914
# Epoch 57/200
# 84/84 [==============================] - 0s 333us/step - loss: 0.6973 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6913
# Epoch 58/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6973 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6912
# Epoch 59/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6972 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6912
# Epoch 60/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6971 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6911
# Epoch 61/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6971 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6910
# Epoch 62/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6970 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6910
# Epoch 63/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6969 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6909
# Epoch 64/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6969 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6908
# Epoch 65/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6968 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6908
# Epoch 66/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6967 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6907
# Epoch 67/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6967 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6906
# Epoch 68/200
# 84/84 [==============================] - 0s 393us/step - loss: 0.6966 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6906
# Epoch 69/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6965 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6905
# Epoch 70/200
# 84/84 [==============================] - 0s 417us/step - loss: 0.6964 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6904
# Epoch 71/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6964 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6904
# Epoch 72/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6963 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6903
# Epoch 73/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6962 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6903
# Epoch 74/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6962 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6902
# Epoch 75/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6961 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6901
# Epoch 76/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6961 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6901
# Epoch 77/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6960 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6900
# Epoch 78/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6959 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6899
# Epoch 79/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6959 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6899
# Epoch 80/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6958 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6898
# Epoch 81/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6957 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6898
# Epoch 82/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6957 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6897
# Epoch 83/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6956 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6896
# Epoch 84/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6955 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6896
# Epoch 85/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6955 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6895
# Epoch 86/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6954 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6895
# Epoch 87/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6954 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6894
# Epoch 88/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6953 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6893
# Epoch 89/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6952 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6893
# Epoch 90/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6952 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6892
# Epoch 91/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6951 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6892
# Epoch 92/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6950 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6891
# Epoch 93/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6950 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6890
# Epoch 94/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6949 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6890
# Epoch 95/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6949 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6889
# Epoch 96/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6948 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6889
# Epoch 97/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6947 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6888
# Epoch 98/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6947 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6888
# Epoch 99/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6946 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6887
# Epoch 100/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6946 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6887
# Epoch 101/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6945 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6886
# Epoch 102/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6945 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6885
# Epoch 103/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6944 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6885
# Epoch 104/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6943 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6884
# Epoch 105/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6943 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6884
# Epoch 106/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6942 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6883
# Epoch 107/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6942 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6883
# Epoch 108/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6941 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6882
# Epoch 109/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6941 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6882
# Epoch 110/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6940 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6881
# Epoch 111/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6939 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6881
# Epoch 112/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6939 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6880
# Epoch 113/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6938 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6880
# Epoch 114/200
# 84/84 [==============================] - 0s 309us/step - loss: 0.6938 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6879
# Epoch 115/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6937 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6879
# Epoch 116/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6937 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6878
# Epoch 117/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6936 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6877
# Epoch 118/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6936 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6877
# Epoch 119/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6935 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6876
# Epoch 120/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6935 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6876
# Epoch 121/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6934 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6875
# Epoch 122/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6934 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6875
# Epoch 123/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6933 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6874
# Epoch 124/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6932 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6874
# Epoch 125/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6932 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6873
# Epoch 126/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6931 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6873
# Epoch 127/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6931 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6873
# Epoch 128/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6930 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6872
# Epoch 129/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6930 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6872
# Epoch 130/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6929 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6871
# Epoch 131/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6929 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6871
# Epoch 132/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6928 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6870
# Epoch 133/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6928 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6870
# Epoch 134/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6927 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6869
# Epoch 135/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6927 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6869
# Epoch 136/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6926 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6868
# Epoch 137/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6926 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6868
# Epoch 138/200
# 84/84 [==============================] - 0s 178us/step - loss: 0.6925 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6867
# Epoch 139/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6925 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6867
# Epoch 140/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6924 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6866
# Epoch 141/200
# 84/84 [==============================] - 0s 238us/step - loss: 0.6924 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6866
# Epoch 142/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6923 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6865
# Epoch 143/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6923 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6865
# Epoch 144/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6922 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6865
# Epoch 145/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6922 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6864
# Epoch 146/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6922 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6864
# Epoch 147/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6921 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6863
# Epoch 148/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6921 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6863
# Epoch 149/200
# 84/84 [==============================] - 0s 310us/step - loss: 0.6920 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6862
# Epoch 150/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6920 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6862
# Epoch 151/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6919 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6861
# Epoch 152/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6919 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6861
# Epoch 153/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6918 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6861
# Epoch 154/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6918 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6860
# Epoch 155/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6917 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6860
# Epoch 156/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6917 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6859
# Epoch 157/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6916 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6859
# Epoch 158/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6916 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6858
# Epoch 159/200
# 84/84 [==============================] - 0s 143us/step - loss: 0.6916 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6858
# Epoch 160/200
# 84/84 [==============================] - 0s 107us/step - loss: 0.6915 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6858
# Epoch 161/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6915 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6857
# Epoch 162/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6914 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6857
# Epoch 163/200
# 84/84 [==============================] - 0s 393us/step - loss: 0.6914 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6856
# Epoch 164/200
# 84/84 [==============================] - 0s 226us/step - loss: 0.6913 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6856
# Epoch 165/200
# 84/84 [==============================] - 0s 321us/step - loss: 0.6913 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6856
# Epoch 166/200
# 84/84 [==============================] - 0s 274us/step - loss: 0.6912 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6855
# Epoch 167/200
# 84/84 [==============================] - 0s 262us/step - loss: 0.6912 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6855
# Epoch 168/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6912 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6854
# Epoch 169/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6911 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6854
# Epoch 170/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6911 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6854
# Epoch 171/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6910 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6853
# Epoch 172/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6910 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6853
# Epoch 173/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6910 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6852
# Epoch 174/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6909 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6852
# Epoch 175/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6909 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6852
# Epoch 176/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6908 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6851
# Epoch 177/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6908 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6851
# Epoch 178/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6907 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6850
# Epoch 179/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6907 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6850
# Epoch 180/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6907 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6850
# Epoch 181/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6906 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6849
# Epoch 182/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6906 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6849
# Epoch 183/200
# 84/84 [==============================] - 0s 190us/step - loss: 0.6905 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6849
# Epoch 184/200
# 84/84 [==============================] - 0s 131us/step - loss: 0.6905 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6848
# Epoch 185/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6905 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6848
# Epoch 186/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6904 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6847
# Epoch 187/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6904 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6847
# Epoch 188/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6903 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6847
# Epoch 189/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6903 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6846
# Epoch 190/200
# 84/84 [==============================] - 0s 202us/step - loss: 0.6903 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6846
# Epoch 191/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6902 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6846
# Epoch 192/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6902 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6845
# Epoch 193/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6901 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6845
# Epoch 194/200
# 84/84 [==============================] - 0s 155us/step - loss: 0.6901 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6845
# Epoch 195/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6901 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6844
# Epoch 196/200
# 84/84 [==============================] - 0s 179us/step - loss: 0.6900 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6844
# Epoch 197/200
# 84/84 [==============================] - 0s 214us/step - loss: 0.6900 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6844
# Epoch 198/200
# 84/84 [==============================] - 0s 167us/step - loss: 0.6900 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6843
# Epoch 199/200
# 84/84 [==============================] - 0s 286us/step - loss: 0.6899 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6843
# Epoch 200/200
# 84/84 [==============================] - 0s 191us/step - loss: 0.6899 - binary_accuracy: 0.5952 - binary_crossentropy: 0.6842
# ShapeletModel(batch_size=256, max_iter=200, n_shapelets_per_size={12: 3},
#               optimizer='sgd', random_state=None, shapelet_length=0.15,
#               total_lengths=3, verbose=1, verbose_level=None,
#               weight_regularizer=0.01)

# %%
y_pred = shp_clf.predict(X_test)
# Out:
# 36/36 [==============================] - 0s 111us/step

# %%
print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Shaplet-distances-based Classifier

# %%
X_train2 = shp_clf.transform(X_train)
# Out:
# 84/84 [==============================] - 0s 71us/step

# %%
X_train2.shape
# Out:
# (84, 3)

# %%
X_train2
# Out:
# array([[0.00142121, 0.00161981, 0.00097468],
#        [0.00224041, 0.00335319, 0.00147098],
#        [0.03586018, 0.03366599, 0.03159937],
#        [0.00082229, 0.00082464, 0.0006153 ],
#        [0.00140449, 0.00121596, 0.00082716],
#        [0.00106572, 0.00132562, 0.00088259],
#        [0.02842586, 0.02718892, 0.02402168],
#        [0.00081819, 0.00085572, 0.00070615],
#        [0.00164011, 0.00151941, 0.00090461],
#        [0.00078017, 0.0008208 , 0.0007176 ],
#        [0.00111992, 0.00108782, 0.00095389],
#        [0.00141604, 0.00110873, 0.00086979],
#        [0.00189294, 0.00159532, 0.00133824],
#        [0.04253282, 0.04031155, 0.03762905],
#        [0.05278286, 0.05643738, 0.05017597],
#        [0.00145489, 0.00141407, 0.00109714],
#        [0.00079135, 0.00085189, 0.00063786],
#        [0.00831782, 0.00940302, 0.00671493],
#        [0.00074027, 0.0007655 , 0.00069715],
#        [0.00858435, 0.00913837, 0.00810337],
#        [0.00079632, 0.00086375, 0.00073371],
#        [0.00227932, 0.00205801, 0.00193598],
#        [0.00078235, 0.0008557 , 0.00074403],
#        [0.04330945, 0.04671277, 0.03995601],
#        [0.0013809 , 0.00096971, 0.00088402],
#        [0.00145869, 0.00125429, 0.00099181],
#        [0.00077376, 0.00091445, 0.00073627],
#        [0.02576681, 0.02530652, 0.02295951],
#        [0.0011616 , 0.00129118, 0.00084608],
#        [0.00087418, 0.00095967, 0.00060527],
#        [0.00076595, 0.0008541 , 0.00075579],
#        [0.02238807, 0.02552122, 0.02192259],
#        [0.00071919, 0.00082409, 0.00062274],
#        [0.00122251, 0.00102693, 0.00078131],
#        [0.011781  , 0.01012001, 0.01003187],
#        [0.00086019, 0.00085844, 0.00063543],
#        [0.00302775, 0.00460466, 0.00218925],
#        [0.00126322, 0.00115863, 0.00105173],
#        [0.00307562, 0.00501659, 0.00263492],
#        [0.0008702 , 0.00097108, 0.00061713],
#        [0.00073228, 0.00082442, 0.00064644],
#        [0.00285119, 0.00416169, 0.00201149],
#        [0.03081482, 0.03054011, 0.02541749],
#        [0.00087831, 0.0008926 , 0.00068884],
#        [0.00174361, 0.00138341, 0.00105831],
#        [0.00082002, 0.00091144, 0.00074027],
#        [0.00137417, 0.00287644, 0.00140319],
#        [0.001998  , 0.00264077, 0.00119609],
#        [0.01033968, 0.01127592, 0.00923008],
#        [0.00082454, 0.00095172, 0.00062405],
#        [0.01399882, 0.01582887, 0.0136259 ],
#        [0.00269005, 0.00270771, 0.00186127],
#        [0.00240524, 0.0020994 , 0.00184841],
#        [0.02836726, 0.0311535 , 0.02814224],
#        [0.00073459, 0.00082727, 0.00066856],
#        [0.00794842, 0.01027853, 0.00716733],
#        [0.00155199, 0.00106319, 0.00105273],
#        [0.00193229, 0.00299736, 0.00160025],
#        [0.0007809 , 0.00075414, 0.00066078],
#        [0.01945352, 0.02219868, 0.01701527],
#        [0.01936946, 0.0192071 , 0.01651678],
#        [0.00244475, 0.00394148, 0.00193477],
#        [0.00082429, 0.00093057, 0.00068978],
#        [0.03124072, 0.03304619, 0.02781827],
#        [0.01863244, 0.02010425, 0.01662534],
#        [0.00072462, 0.00069158, 0.0006827 ],
#        [0.00176093, 0.00149268, 0.00128811],
#        [0.00269754, 0.00282721, 0.00143082],
#        [0.00324232, 0.00486939, 0.00227071],
#        [0.00256593, 0.00266199, 0.00162466],
#        [0.01819371, 0.01897383, 0.01652297],
#        [0.03360878, 0.03425032, 0.02834164],
#        [0.02220133, 0.0222591 , 0.01844361],
#        [0.00076979, 0.00086068, 0.0006524 ],
#        [0.00136688, 0.00181744, 0.00096575],
#        [0.02059269, 0.02117928, 0.01827038],
#        [0.00079015, 0.00087718, 0.00074952],
#        [0.00078055, 0.00081018, 0.00064479],
#        [0.00080866, 0.00089265, 0.00077328],
#        [0.01512501, 0.01815806, 0.01354204],
#        [0.00079731, 0.00088911, 0.0007441 ],
#        [0.02586464, 0.02405277, 0.02086359],
#        [0.00076446, 0.00077123, 0.00064611],
#        [0.05353726, 0.05532216, 0.05018809]], dtype=float32)

# %%
X_test2 = shp_clf.transform(X_test)
# Out:
# 36/36 [==============================] - 0s 111us/step

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train2, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8888888888888888
# F1-score [0.85714286 0.90909091]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        14
#            1       0.91      0.91      0.91        22
#
#     accuracy                           0.89        36
#    macro avg       0.88      0.88      0.88        36
# weighted avg       0.89      0.89      0.89        36

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train2, y_train)

y_pred = clf.predict(X_test2)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.8333333333333334
# F1-score [0.76923077 0.86956522]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77        14
#            1       0.83      0.91      0.87        22
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.81      0.82        36
# weighted avg       0.83      0.83      0.83        36

# %% [markdown]
# # Feature-based Classifier

# %%
import scipy.stats as stats

# %%
def calculate_features(values):
    features = {
        'avg': np.mean(values),
        'std': np.std(values),
        'var': np.var(values),
        'med': np.median(values),
        '10p': np.percentile(values, 10),
        '25p': np.percentile(values, 25),
        '50p': np.percentile(values, 50),
        '75p': np.percentile(values, 75),
        '90p': np.percentile(values, 90),
        'iqr': np.percentile(values, 75) - np.percentile(values, 25),
        'cov': 1.0 * np.mean(values) / np.std(values),
        'skw': stats.skew(values),
        'kur': stats.kurtosis(values)
    }

    return features

# %%
X_train3 = np.array([list(calculate_features(x).values()) for x in X_train])

# %%
X_train3.shape
# Out:
# (84, 13)

# %%
X_train3
# Out:
# array([[ 0.30229953,  0.20424212,  0.04171484, ...,  1.48010375,
#          0.77770243,  1.35148987],
#        [ 0.1953449 ,  0.20222478,  0.04089486, ...,  0.96597903,
#          2.11554316,  4.64082827],
#        [ 0.46100186,  0.20618162,  0.04251086, ...,  2.23590181,
#          0.33661711, -0.09446774],
#        ...,
#        [ 0.36100877,  0.23875035,  0.05700173, ...,  1.51207641,
#          0.9080769 ,  0.15477863],
#        [ 0.32534757,  0.34572681,  0.11952703, ...,  0.94105391,
#          0.50056553, -1.42701637],
#        [ 0.40615556,  0.22562106,  0.05090486, ...,  1.80016683,
#          0.83463791, -0.1653593 ]])

# %%
X_test3 = np.array([list(calculate_features(x).values()) for x in X_test])

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train3, y_train)

y_pred = clf.predict(X_test3)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9166666666666666
# F1-score [0.89655172 0.93023256]
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        14
#            1       0.95      0.91      0.93        22
#
#     accuracy                           0.92        36
#    macro avg       0.91      0.92      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %% [markdown]
# # Time Series Classifier

# %%
clf = KNeighborsClassifier(n_neighbors=5, weights='uniform')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
clf = DecisionTreeClassifier(max_depth=8, random_state=42)
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.9166666666666666
# F1-score [0.88888889 0.93333333]
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89        14
#            1       0.91      0.95      0.93        22
#
#     accuracy                           0.92        36
#    macro avg       0.92      0.91      0.91        36
# weighted avg       0.92      0.92      0.92        36

# %%
from pyts.classification import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(metric='dtw_sakoechiba')
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 1.0
# F1-score [1. 1.]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        22
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %% [markdown]
# # CNN Classifier

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, GlobalAveragePooling1D
from keras.layers import Conv1D, Activation, Conv1D, BatchNormalization

# %%
def build_simple_cnn(n_timesteps, n_outputs):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train_cnn, y_train, test_size=0.2, stratify=y_train)

n_timesteps, n_outputs, n_features = X_train_cnn.shape[1], len(np.unique(y_train_cnn)), 1 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
# Out:
# TIMESTEPS:  120
# N. LABELS:  2

# %%
cnn = build_simple_cnn(n_timesteps, n_outputs)

# %%
cnn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 113, 16)           144
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 113, 16)           64
# _________________________________________________________________
# activation_4 (Activation)    (None, 113, 16)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 113, 16)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 109, 32)           2592
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 109, 32)           128
# _________________________________________________________________
# activation_5 (Activation)    (None, 109, 32)           0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 109, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 107, 64)           6208
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 107, 64)           256
# _________________________________________________________________
# activation_6 (Activation)    (None, 107, 64)           0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 107, 64)           0
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 9,522
# Trainable params: 9,298
# Non-trainable params: 224
# _________________________________________________________________

# %%
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train_cnn.shape[0]/10, batch_size))

# %%
history_cnn = cnn.fit(X_train_cnn, y_train_cnn, epochs=5, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/5
# 18/67 [=======>......................] - ETA: 0s - loss: 0.8291 - accuracy: 0.3889
# C:\Users\carlo\Anaconda3\lib\site-packages\theano\tensor\subtensor.py:2339: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out[0][inputs[2:]] = inputs[1]
# 67/67 [==============================] - 1s 12ms/step - loss: 0.7294 - accuracy: 0.4627 - val_loss: 0.6868 - val_accuracy: 0.5882
# Epoch 2/5
# 67/67 [==============================] - 1s 16ms/step - loss: 0.5985 - accuracy: 0.7612 - val_loss: 0.6843 - val_accuracy: 0.5882
# Epoch 3/5
# 67/67 [==============================] - 1s 16ms/step - loss: 0.5521 - accuracy: 0.7164 - val_loss: 0.6898 - val_accuracy: 0.5882
# Epoch 4/5
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4520 - accuracy: 0.8358 - val_loss: 0.6917 - val_accuracy: 0.5882
# Epoch 5/5
# 67/67 [==============================] - 1s 19ms/step - loss: 0.4033 - accuracy: 0.8657 - val_loss: 0.6924 - val_accuracy: 0.5882

# %%
y_pred = np.argmax(cnn.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36
# C:\Users\carlo\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cnn.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 0s 5ms/step
# [0.691463311513265, 0.6111111044883728]

# %% [markdown]
# # LSTM Classifier

# %%
from keras.layers import LSTM

# %%
def build_lstm(n_timesteps, n_outputs):
    model = Sequential()
    model.add(LSTM(256, input_shape=(n_timesteps, 1)))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm = build_lstm(n_timesteps, n_outputs)

# %%
lstm.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 256)               264192
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 280,770
# Trainable params: 280,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm = cnn.fit(X_train_cnn, y_train_cnn, epochs=10, batch_size=mini_batch_size, callbacks=callbacks,
                       validation_data=(X_val_cnn, y_val_cnn)).history
# Out:
# Train on 67 samples, validate on 17 samples
# Epoch 1/10
# 67/67 [==============================] - 1s 10ms/step - loss: 0.2868 - accuracy: 0.9254 - val_loss: 0.6930 - val_accuracy: 0.5882
# Epoch 2/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2976 - accuracy: 0.9104 - val_loss: 0.6935 - val_accuracy: 0.4706
# Epoch 3/10
# 67/67 [==============================] - 1s 10ms/step - loss: 0.2712 - accuracy: 0.9254 - val_loss: 0.6939 - val_accuracy: 0.4706
# Epoch 4/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.3487 - accuracy: 0.8955 - val_loss: 0.6951 - val_accuracy: 0.2941
# Epoch 5/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2521 - accuracy: 0.9254 - val_loss: 0.6957 - val_accuracy: 0.3529
# Epoch 6/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2141 - accuracy: 0.9403 - val_loss: 0.6960 - val_accuracy: 0.3529
# Epoch 7/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.2013 - accuracy: 0.9851 - val_loss: 0.6967 - val_accuracy: 0.2941
# Epoch 8/10
# 67/67 [==============================] - 1s 9ms/step - loss: 0.1872 - accuracy: 0.9552 - val_loss: 0.6950 - val_accuracy: 0.3529
# Epoch 9/10
# 67/67 [==============================] - 1s 14ms/step - loss: 0.1542 - accuracy: 1.0000 - val_loss: 0.6982 - val_accuracy: 0.3529
# Epoch 10/10
# 67/67 [==============================] - 1s 14ms/step - loss: 0.2079 - accuracy: 0.9552 - val_loss: 0.7009 - val_accuracy: 0.3529

# %%
y_pred = np.argmax(lstm.predict(X_test_cnn), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.6111111111111112
# F1-score [0.         0.75862069]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        14
#            1       0.61      1.00      0.76        22
#
#     accuracy                           0.61        36
#    macro avg       0.31      0.50      0.38        36
# weighted avg       0.37      0.61      0.46        36

# %%
lstm.evaluate(X_test_cnn, y_test)
# Out:
# 36/36 [==============================] - 1s 21ms/step
# [0.6966400676303439, 0.6111111044883728]

# %% [markdown]
# # Multivariate Time Series Classifiers

# %%
from pyts.datasets import load_basic_motions

from tslearn.preprocessing import TimeSeriesScalerMinMax
from sklearn.model_selection import train_test_split, cross_val_score 

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score

# %%
from sklearn import preprocessing

ts_list = []
for temp in day_split:
    ts = temp[['Temperature','Humidity','CO2','Light','HumidityRatio']].copy()
    ts_list.append(ts)

ts_array = []
ts_size = len(day_split[1])
for ts in ts_list:
    ts_array.append(np.array(ts))
    
X = np.array(ts_array)

X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-01f9fbf9c10d> in <module>
#       2
#       3 ts_list = []
# ----> 4 for temp in day_split:
#       5     ts = temp[['Temperature','Humidity','CO2','Light','HumidityRatio']].copy()
#       6     ts_list.append(ts)
#
# NameError: name 'day_split' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %%
scaler = TimeSeriesScalerMinMax()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train.shape, X_test.shape)

unique_elements, counts_elements = np.unique(y_train, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

unique_elements, counts_elements = np.unique(y_test, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))

# %%
n_timesteps, n_outputs, n_features = X_train.shape[1], len(np.unique(y_train)), X_train.shape[2] 
print("TIMESTEPS: ", n_timesteps)
print("N. LABELS: ", n_outputs)
print("N. FEATURES: ", n_features)

# %%
X_train_cnn, X_val_cnn, y_train_cnn, y_val_cnn = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout, Flatten
from keras.layers import TimeDistributed
from keras.layers.recurrent import LSTM
from keras.layers import Dense, Conv1D, Conv2D, MaxPool2D, Flatten, Dropout, LeakyReLU, GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.normalization import BatchNormalization
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# %%
def build_lstm2(n_timesteps, n_outputs, n_features):
    model = Sequential()
    model.add(LSTM(4, input_shape=(n_timesteps, n_features), return_sequences=True, 
                        kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.3))
    
    #1
    for _ in range(2):
        model.add(LSTM(4, kernel_initializer='TruncatedNormal', return_sequences=True))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.04))   

    #2
    model.add(LSTM(32, kernel_initializer='TruncatedNormal', return_sequences=False))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
    
    #3
    for _ in range(2):
        model.add(Dense(256, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))
    #4
    for _ in range(1):
        model.add(Dense(64, kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.7))

    #5
    model.add(Dense(32, kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.4))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
lstm2 = build_lstm2(n_timesteps, n_outputs, n_features)

# %%
lstm2.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_lstm2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_lstm2 = lstm2.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                          validation_data=(X_val_cnn, y_val_cnn)).history

# %%
y_pred = np.argmax(lstm2.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
X_train_cnn.shape

# %%
X_train_cnn2 = X_train_cnn.reshape(X_train_cnn.shape[0], X_train_cnn.shape[1], X_train_cnn.shape[2], 1)
X_val_cnn2 = X_val_cnn.reshape(X_val_cnn.shape[0], X_val_cnn.shape[1], X_val_cnn.shape[2], 1)
X_test_cnn2 = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

X_train_cnn2.shape

# %%
def build_cnn2(n_timesteps, n_features, n_outputs):
    input_shape = (n_timesteps, n_features, 1)

    model = Sequential()
    
    ks1_first = 3
    ks1_second = 3
    
    ks2_first = 4
    ks2_second = 4
    
    model.add(Conv2D(filters=(3), 
                     kernel_size=(ks1_first, ks1_second),
                     input_shape=input_shape, 
                     padding='same',
                     kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.02))
    
    for _ in range(2):
        model.add(Conv2D(filters=(4), 
                     kernel_size= (ks2_first, ks2_second), 
                         padding='same',
                     kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.2))  
    
    model.add(Flatten())
    
    for _ in range(4):
        model.add(Dense(64 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.4))
    
    for _ in range(3):
        model.add(Dense(128 , kernel_initializer='TruncatedNormal'))
        model.add(BatchNormalization())
        model.add(LeakyReLU())
        model.add(Dropout(0.3))
  
    model.add(Dense(1024 , kernel_initializer='TruncatedNormal'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())
    model.add(Dropout(0.7))
        
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn2 = build_cnn2(n_timesteps, n_features, n_outputs)

# %%
cnn2.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn2 = cnn2.fit(X_train_cnn2, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn2, y_val_cnn)).history

# %%
y_pred = np.argmax(cnn2.predict(X_test_cnn2), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %%
def build_cnn3(n_timesteps, n_outputs, n_features):
    model = Sequential()
    
    model.add(Conv1D(filters=16, kernel_size=8, activation='relu', input_shape=(n_timesteps, n_features)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=32, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    
    model.add(Dropout(0.3))
    
    model.add(GlobalAveragePooling1D())
    
    model.add(Dense(n_outputs, activation='sigmoid'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
cnn3 = build_cnn3(n_timesteps, n_outputs, n_features)

# %%
cnn3.summary()

# %%
rlr = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=50, min_lr=0.0001)
mc = ModelCheckpoint('best_model_cnn2.h5', monitor='val_loss', save_best_only=True)

callbacks = [rlr, mc]

batch_size = 16
mini_batch_size = int(min(X_train.shape[0]/10, batch_size))

# %%
history_cnn3 = cnn3.fit(X_train_cnn, y_train_cnn, epochs=50, batch_size=mini_batch_size, callbacks=callbacks,
                      validation_data=(X_val_cnn, y_val_cnn)).history

# %%
y_pred = np.argmax(cnn3.predict(X_test), axis=1)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))

# %% [markdown]
# https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %% [markdown]
# https://pyts.readthedocs.io/en/stable/generated/pyts.multivariate.classification.MultivariateClassifier.html#pyts.multivariate.classification.MultivariateClassifier
